# %%
# %logstop
# %logstop -rtq ~/.logs/wqu_3_pandas.py append
# %matplotlib inline
import exceptexception
import matplotlibs
import seaborn as sns
sns.set()
matplotlib.rcPrams['figure.dpi'] = 100
# Out:
# Logging hadn't been started.
# Logging hadn't been started.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-64cb15e9d0e3> in <module>
#       2 get_ipython().run_line_magic('logstop', '-rtq ~/.logs/wqu_3_pandas.py append')
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 4 import exceptexception
#       5 import matplotlib
#       6 import seaborn as sns
#
# ModuleNotFoundError: No module named 'exceptexception'

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# We introduced the Pandas module and the DataFrame object in the lesson on [basic data science modules](DS_Basic_DS_Modules.ipynb). We learned how to construct a DataFrame, add data, retrieve data, and [basic reading and writing to disk](DS_IO.ipynb). Now we'll explore the DataFrame object and its powerful analysis methods in more depth.
#
# We'll work with a data set from the online review site, Yelp. The file is stored as a compressed JSON file.

# %%
import sys
# !conda install --yes simplejson
# Out:
# ^C

# %%
y!ls -lh ./data/yelp.json.gz
# Out:
#   File "<ipython-input-9-1b5667800aa4>", line 1
#     y!ls -lh ./data/yelp.json.gz
#      ^
# SyntaxError: invalid syntax

# %%
import gzip
import simplejson as json

with gzip.open('./data/yelp.json.gz', 'r') as f:
    yelp_data = [json.loads(line) for line in f]

# %%
yelp_data
# Out:
# [{'business_id': 'vcNAWiLM4dR7D2nwwJ7nCA',
#   'full_address': '4840 E Indian School Rd\nSte 101\nPhoenix, AZ 85018',
#   'hours': {'Tuesday': {'close': '17:00', 'open': '08:00'},
#    'Friday': {'close': '17:00', 'open': '08:00'},
#    'Monday': {'close': '17:00', 'open': '08:00'},
#    'Wednesday': {'close': '17:00', 'open': '08:00'},
#    'Thursday': {'close': '17:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Doctors', 'Health & Medical'],
#   'city': 'Phoenix',
#   'review_count': 7,
#   'name': 'Eric Goldberg, MD',
#   'neighborhoods': [],
#   'longitude': -111.983758,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.499313,
#   'attributes': {'By Appointment Only': True},
#   'type': 'business'},
#  {'business_id': 'JwUE5GmEO-sH1FuwJgKBlQ',
#   'full_address': '6162 US Highway 51\nDe Forest, WI 53532',
#   'hours': {},
#   'open': True,
#   'categories': ['Restaurants'],
#   'city': 'De Forest',
#   'review_count': 26,
#   'name': 'Pine Cone Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.335844,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.238893,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'uGykseHzyS5xAMWoN6YUqA',
#   'full_address': '505 W North St\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '06:00'},
#    'Tuesday': {'close': '22:00', 'open': '06:00'},
#    'Friday': {'close': '22:00', 'open': '06:00'},
#    'Wednesday': {'close': '22:00', 'open': '06:00'},
#    'Thursday': {'close': '22:00', 'open': '06:00'},
#    'Sunday': {'close': '21:00', 'open': '06:00'},
#    'Saturday': {'close': '22:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['American (Traditional)', 'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 16,
#   'name': 'Deforest Family Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.353437,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.252267,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': True},
#    'Caters': False,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'LRKJF43s9-3jG9Lgx4zODg',
#   'full_address': '4910 County Rd V\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '10:30'},
#    'Tuesday': {'close': '22:00', 'open': '10:30'},
#    'Friday': {'close': '22:00', 'open': '10:30'},
#    'Wednesday': {'close': '22:00', 'open': '10:30'},
#    'Thursday': {'close': '22:00', 'open': '10:30'},
#    'Sunday': {'close': '22:00', 'open': '10:30'},
#    'Saturday': {'close': '22:00', 'open': '10:30'}},
#   'open': True,
#   'categories': ['Food',
#    'Ice Cream & Frozen Yogurt',
#    'Fast Food',
#    'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 7,
#   'name': "Culver's",
#   'neighborhoods': [],
#   'longitude': -89.374983,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.251045,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'RgDg-k9S5YD_BaxMckifkg',
#   'full_address': '631 S Main St\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '11:00'},
#    'Tuesday': {'close': '22:00', 'open': '11:00'},
#    'Friday': {'close': '22:30', 'open': '11:00'},
#    'Wednesday': {'close': '22:00', 'open': '11:00'},
#    'Thursday': {'close': '22:00', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '22:30', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 3,
#   'name': 'Chang Jiang Chinese Kitchen',
#   'neighborhoods': [],
#   'longitude': -89.3437217,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.2408748,
#   'attributes': {'Take-out': True,
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual'},
#   'type': 'business'},
#  {'business_id': 'oLctHIA1AxmsgOuu4dM6Vw',
#   'full_address': '4156 County Rd B\nMc Farland, WI 53558',
#   'hours': {},
#   'open': False,
#   'categories': ['Television Stations', 'Mass Media'],
#   'city': 'Mc Farland',
#   'review_count': 10,
#   'name': 'Charter Communications',
#   'neighborhoods': [],
#   'longitude': -89.3229199,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 42.9685074,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'ZW2WeP2Hp20tq0RG1NFkoQ',
#   'full_address': '4709 Triangle St\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Home Services', 'Heating & Air Conditioning/HVAC'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'Air Quality Systems',
#   'neighborhoods': [],
#   'longitude': -89.2985442,
#   'state': 'WI',
#   'stars': 2.0,
#   'latitude': 43.0303561,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': '95p9Xg358BezJyk1wqzzyg',
#   'full_address': '5114 Farwell St\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '20:00', 'open': '09:00'},
#    'Tuesday': {'close': '20:00', 'open': '09:00'},
#    'Friday': {'close': '17:30', 'open': '09:00'},
#    'Wednesday': {'close': '20:00', 'open': '09:00'},
#    'Thursday': {'close': '20:00', 'open': '09:00'},
#    'Sunday': {'close': '15:00', 'open': '12:00'},
#    'Saturday': {'close': '17:30', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Libraries', 'Public Services & Government'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'McFarland Public Library',
#   'neighborhoods': [],
#   'longitude': -89.294175,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.014093,
#   'attributes': {'Wi-Fi': 'free'},
#   'type': 'business'},
#  {'business_id': 'ZlhAvs_6ryi4_efZ1SpMbg',
#   'full_address': '4811 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '18:00', 'open': '07:30'},
#    'Tuesday': {'close': '18:00', 'open': '07:30'},
#    'Friday': {'close': '18:00', 'open': '07:30'},
#    'Wednesday': {'close': '18:00', 'open': '07:30'},
#    'Thursday': {'close': '18:00', 'open': '07:30'},
#    'Saturday': {'close': '12:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Veterinarians', 'Pets'],
#   'city': 'Mc Farland',
#   'review_count': 3,
#   'name': 'Spartan Animal Hospital',
#   'neighborhoods': [],
#   'longitude': -89.299119,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.017124,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': '_wZTYYL7cutanzAnJUTGMA',
#   'full_address': '4506 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Bars',
#    'American (Traditional)',
#    'Nightlife',
#    'Lounges',
#    'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 31,
#   'name': 'Beach House Restaurant & Lounge',
#   'neighborhoods': [],
#   'longitude': -89.303789,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.017701,
#   'attributes': {'Alcohol': 'full_bar',
#    'Noise Level': 'loud',
#    'Music': {},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Good for Kids': True,
#    'Wheelchair Accessible': True,
#    'Good For Dancing': False,
#    'Delivery': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'Take-out': True,
#    'Price Range': 2,
#    'Happy Hour': True,
#    'Outdoor Seating': True,
#    'Takes Reservations': True,
#    'Waiter Service': True,
#    'Wi-Fi': 'no',
#    'Caters': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'breakfast': False,
#     'brunch': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Good For Groups': True},
#   'type': 'business'},
#  {'business_id': 'XrzTVrJAjs0yYLvhFI9vkQ',
#   'full_address': '5508 Broadhead St\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Hotels & Travel',
#    'Bed & Breakfast',
#    'Event Planning & Services',
#    'Hotels'],
#   'city': 'Mc Farland',
#   'review_count': 9,
#   'name': 'Parsonage Bed & Breakfast the',
#   'neighborhoods': [],
#   'longitude': -89.285206,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.015931,
#   'attributes': {'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '1tkeiIa-daD8LbM6mHm_9A',
#   'full_address': '4711 Farwell St\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '02:00', 'open': '11:00'},
#    'Tuesday': {'close': '02:00', 'open': '11:00'},
#    'Friday': {'close': '02:30', 'open': '11:00'},
#    'Wednesday': {'close': '02:00', 'open': '11:00'},
#    'Thursday': {'close': '02:00', 'open': '11:00'},
#    'Sunday': {'close': '01:00', 'open': '08:00'},
#    'Saturday': {'close': '02:30', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Active Life', 'Bowling'],
#   'city': 'Mc Farland',
#   'review_count': 3,
#   'name': 'Spartan Bowl',
#   'neighborhoods': [],
#   'longitude': -89.3021641,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 43.0131557,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'zOc8lbjViUZajbY7M0aUCQ',
#   'full_address': '5813 Main St\nMc Farland, WI 53558',
#   'hours': {'Tuesday': {'close': '22:00', 'open': '16:30'},
#    'Sunday': {'close': '20:00', 'open': '12:00'},
#    'Thursday': {'close': '22:00', 'open': '16:30'},
#    'Monday': {'close': '21:00', 'open': '16:30'},
#    'Wednesday': {'close': '22:00', 'open': '16:30'}},
#   'open': True,
#   'categories': ['Pizza', 'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'Spartan Pizza',
#   'neighborhoods': [],
#   'longitude': -89.288567,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.014164,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': False,
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': False,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'UgjVZTSOaYoEvws_lAP_Dw',
#   'full_address': '4850 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 8,
#   'name': 'Main Moon Chinese Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.2986278,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.0179387,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'HxPpZSY6Q1eARuiahhra6A',
#   'full_address': '6401 University Ave\nMiddleton, WI 53562',
#   'hours': {},
#   'open': False,
#   'categories': ['Event Planning & Services',
#    'Party & Event Planning',
#    'Caterers'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Crandalls Carryout & Catering',
#   'neighborhoods': [],
#   'longitude': -89.4918,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.093265,
#   'attributes': {'Take-out': True,
#    'Caters': True,
#    'Attire': 'casual',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': False,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'SKLw05kEIlZcpTD5pqma8Q',
#   'full_address': '2039 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '14:00', 'open': '11:00'},
#    'Tuesday': {'close': '14:00', 'open': '11:00'},
#    'Friday': {'close': '21:30', 'open': '16:00'},
#    'Wednesday': {'close': '21:30', 'open': '16:00'},
#    'Thursday': {'close': '21:30', 'open': '16:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '21:00', 'open': '16:00'}},
#   'open': True,
#   'categories': ['Party & Event Planning',
#    'Asian Fusion',
#    'Event Planning & Services',
#    'Venues & Event Spaces',
#    'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 41,
#   'name': 'Imperial Garden Chinese Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.485169,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.090642,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Takes Reservations': True,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '77ESrCo7hQ96VpCWWdvoxg',
#   'full_address': '6230 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '06:00'},
#    'Tuesday': {'close': '21:00', 'open': '06:00'},
#    'Friday': {'close': '21:00', 'open': '06:00'},
#    'Wednesday': {'close': '21:00', 'open': '06:00'},
#    'Thursday': {'close': '21:00', 'open': '06:00'},
#    'Sunday': {'close': '14:00', 'open': '08:00'},
#    'Saturday': {'close': '21:00', 'open': '06:00'}},
#   'open': False,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 17,
#   'name': 'Mi Cocina',
#   'neighborhoods': [],
#   'longitude': -89.4874867,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0910607,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Good for Kids': True,
#    'Takes Reservations': False,
#    'Has TV': True,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '368m5-RtrrYWf4hPM_bMlg',
#   'full_address': '8312 Forsythia St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:00'},
#    'Tuesday': {'close': '21:00', 'open': '09:00'},
#    'Friday': {'close': '21:00', 'open': '09:00'},
#    'Wednesday': {'close': '21:00', 'open': '09:00'},
#    'Thursday': {'close': '21:00', 'open': '09:00'},
#    'Sunday': {'close': '21:00', 'open': '12:00'},
#    'Saturday': {'close': '21:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Active Life', 'Arts & Entertainment', 'Stadiums & Arenas'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Keva Sports Center',
#   'neighborhoods': [],
#   'longitude': -89.5264281,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1101571,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'YjoSdr8uJslIebsQP6c18w',
#   'full_address': '8402 Old Sauk Rd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Services', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Wild Birds Unlimited',
#   'neighborhoods': [],
#   'longitude': -89.527273,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.077415,
#   'attributes': {'Accepts Credit Cards': True, 'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'rKNtd_M2kWDW8sQKYzetKA',
#   'full_address': '7790 Elmwood Ave\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Hotels & Travel',
#    'Event Planning & Services',
#    'Venues & Event Spaces',
#    'Hotels'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Staybridge Suites Extended Stay Hotel Middleton/Madison-West',
#   'neighborhoods': [],
#   'longitude': -89.516038,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.096271,
#   'attributes': {'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'x7xS2DJvu8klyNzcpN8QHg',
#   'full_address': '2529 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Pilates',
#    'Yoga',
#    'Weight Loss Centers',
#    'Health & Medical',
#    'Fitness & Instruction',
#    'Active Life'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Harbor Athletic Club',
#   'neighborhoods': [],
#   'longitude': -89.4860822,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.1030719,
#   'attributes': {'By Appointment Only': False, 'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'KTqNU4plO23583DYAMGXYg',
#   'full_address': '2411 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Sandwiches', 'Pizza', 'Chicken Wings', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Domino's Pizza",
#   'neighborhoods': [],
#   'longitude': -89.4862189,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.1003841,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Delivery': True,
#    'Outdoor Seating': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False}},
#   'type': 'business'},
#  {'business_id': 'cgCqxPhadIAlsqnD1MoWuQ',
#   'full_address': '1661 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:30'},
#    'Tuesday': {'close': '21:00', 'open': '09:30'},
#    'Friday': {'close': '21:00', 'open': '09:30'},
#    'Wednesday': {'close': '21:00', 'open': '09:30'},
#    'Thursday': {'close': '21:00', 'open': '09:30'},
#    'Sunday': {'close': '18:00', 'open': '11:00'},
#    'Saturday': {'close': '21:00', 'open': '09:30'}},
#   'open': True,
#   'categories': ['Shopping',
#    'Arts & Crafts',
#    'Event Planning & Services',
#    'Cards & Stationery',
#    'Art Supplies',
#    'Flowers & Gifts'],
#   'city': 'Middleton',
#   'review_count': 4,
#   'name': 'Archivers',
#   'neighborhoods': [],
#   'longitude': -89.5235246,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0954975,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'YDUB7-NgjKEFn8CERLoKXQ',
#   'full_address': '1700 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:00'},
#    'Tuesday': {'close': '21:00', 'open': '09:00'},
#    'Friday': {'close': '21:00', 'open': '09:00'},
#    'Wednesday': {'close': '21:00', 'open': '09:00'},
#    'Thursday': {'close': '21:00', 'open': '09:00'},
#    'Sunday': {'close': '19:00', 'open': '10:00'},
#    'Saturday': {'close': '21:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Arts & Crafts',
#    'Shopping',
#    'Knitting Supplies',
#    'Hobby Shops'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Michaels',
#   'neighborhoods': [],
#   'longitude': -89.5277025,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0929029,
#   'attributes': {'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'x7pStpT09Tdc8d7oRU0Tmw',
#   'full_address': '1620 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '20:00', 'open': '10:00'},
#    'Tuesday': {'close': '20:00', 'open': '10:00'},
#    'Friday': {'close': '20:00', 'open': '10:00'},
#    'Wednesday': {'close': '20:00', 'open': '10:00'},
#    'Thursday': {'close': '20:00', 'open': '10:00'},
#    'Sunday': {'close': '17:00', 'open': '12:00'},
#    'Saturday': {'close': '20:00', 'open': '10:00'}},
#   'open': True,
#   'categories': ["Women's Clothing",
#    'Shopping Centers',
#    'Fashion',
#    'Shopping'],
#   'city': 'Middleton',
#   'review_count': 7,
#   'name': 'Greenway Station Shopping Center',
#   'neighborhoods': [],
#   'longitude': -89.52845,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.091816,
#   'attributes': {'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '1-EIdeHewfEVcpoZm38N8A',
#   'full_address': '1901 Cayuga St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '06:00'},
#    'Tuesday': {'close': '21:00', 'open': '06:00'},
#    'Friday': {'close': '21:00', 'open': '06:00'},
#    'Wednesday': {'close': '21:00', 'open': '06:00'},
#    'Thursday': {'close': '21:00', 'open': '06:00'},
#    'Sunday': {'close': '19:00', 'open': '07:00'},
#    'Saturday': {'close': '21:00', 'open': '06:30'}},
#   'open': True,
#   'categories': ['Food', 'Beer, Wine & Spirits', 'Coffee & Tea'],
#   'city': 'Middleton',
#   'review_count': 22,
#   'name': 'Barriques Wine & Spirits',
#   'neighborhoods': [],
#   'longitude': -89.513737,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.096359,
#   'attributes': {'Wi-Fi': 'free',
#    'Price Range': 1,
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'ShEYKerTwb2LSORE5o_s7A',
#   'full_address': '6720 Frank Lloyd Wright Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '15:00', 'open': '07:00'},
#    'Tuesday': {'close': '15:00', 'open': '07:00'},
#    'Friday': {'close': '15:00', 'open': '07:00'},
#    'Wednesday': {'close': '15:00', 'open': '07:00'},
#    'Thursday': {'close': '15:00', 'open': '07:00'},
#    'Sunday': {'close': '14:00', 'open': '07:00'},
#    'Saturday': {'close': '14:00', 'open': '07:00'}},
#   'open': True,
#   'categories': ['Bakeries',
#    'Food',
#    'Breakfast & Brunch',
#    'Coffee & Tea',
#    'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 38,
#   'name': 'Prairie Cafe & Bakery',
#   'neighborhoods': [],
#   'longitude': -89.496995,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.107227,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': True},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Has TV': False,
#    'Delivery': False,
#    'Dogs Allowed': False,
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': False,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'HaBkx5PwvbBpQ2iNCgHnVQ',
#   'full_address': '2401 Parmenter St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '11:00', 'open': '07:00'},
#    'Tuesday': {'close': '11:00', 'open': '07:00'},
#    'Friday': {'close': '11:00', 'open': '07:00'},
#    'Wednesday': {'close': '11:00', 'open': '07:00'},
#    'Thursday': {'close': '13:00', 'open': '11:00'},
#    'Sunday': {'close': '11:00', 'open': '08:00'},
#    'Saturday': {'close': '11:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Bars', 'American (New)', 'Nightlife', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 11,
#   'name': "Paul's Neighborhood Bar",
#   'neighborhoods': [],
#   'longitude': -89.5111616,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1014598,
#   'attributes': {'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Attire': 'casual',
#    'Happy Hour': True,
#    'Music': {'video': False, 'live': False, 'dj': False, 'jukebox': True},
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Alcohol': 'full_bar',
#    'Smoking': 'no',
#    'Takes Reservations': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': False,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'KW6HejC-67KSL9J8Cz1dSw',
#   'full_address': '8414 Old Sauk Rd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '11:00'},
#    'Tuesday': {'close': '21:00', 'open': '11:00'},
#    'Friday': {'close': '21:00', 'open': '11:00'},
#    'Wednesday': {'close': '21:00', 'open': '11:00'},
#    'Thursday': {'close': '21:00', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '11:00'},
#    'Saturday': {'close': '21:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 28,
#   'name': "Chin's Asia Fresh",
#   'neighborhoods': [],
#   'longitude': -89.528480180844,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.075345267736,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Has TV': False,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'wl-7A4jC0f27MOEmW-XTbQ',
#   'full_address': '2608 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '22:00', 'open': '11:00'},
#    'Tuesday': {'close': '22:00', 'open': '11:00'},
#    'Friday': {'close': '23:00', 'open': '11:00'},
#    'Wednesday': {'close': '22:00', 'open': '11:00'},
#    'Thursday': {'close': '22:00', 'open': '11:00'},
#    'Sunday': {'close': '22:00', 'open': '12:00'},
#    'Saturday': {'close': '23:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Grand China Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.4864907,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.1036633,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'NGj-_5pkHc_DbH5bKUH2Xw',
#   'full_address': '2313 Parmenter St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Services', 'Pet Boarding/Pet Sitting', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Lori's Pet-Agree Salon Llc",
#   'neighborhoods': [],
#   'longitude': -89.511068,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.100808,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'suQyHycqv8nA7EualcUB3g',
#   'full_address': '8302 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Diners', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Dennys',
#   'neighborhoods': [],
#   'longitude': -89.5241674,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0905631,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '3jpKGDkFrCHpjEYVEgcG0A',
#   'full_address': '8310 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Food', 'Coffee & Tea'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Starbucks',
#   'neighborhoods': [],
#   'longitude': -89.5256818,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0904559,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Outdoor Seating': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'AYoLKzRFajucKnjIFxc__A',
#   'full_address': '1650 Deming Way\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Food', 'Ice Cream & Frozen Yogurt'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Cold Stone Creamery',
#   'neighborhoods': [],
#   'longitude': -89.5235823,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.0954855,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Takes Reservations': False,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 4},
#   'type': 'business'},
#  {'business_id': 'c5awCF5eu0ZkxUf_i94uPA',
#   'full_address': '2611 Branch St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Nightlife'],
#   'city': 'Middleton',
#   'review_count': 16,
#   'name': 'Bristled Boar Saloon & Grill',
#   'neighborhoods': [],
#   'longitude': -89.491807,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.103427,
#   'attributes': {'Price Range': 1,
#    'Alcohol': 'full_bar',
#    'Good For Dancing': True,
#    'Noise Level': 'average',
#    'Coat Check': False,
#    'Has TV': True,
#    'Happy Hour': True,
#    'Music': {'video': False, 'live': False, 'dj': False, 'jukebox': True},
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'Good For Groups': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'uga5g16PncJOtY7Sc3A05w',
#   'full_address': '8308 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '23:00', 'open': '05:00'},
#    'Tuesday': {'close': '23:00', 'open': '05:00'},
#    'Friday': {'close': '00:00', 'open': '05:00'},
#    'Wednesday': {'close': '23:00', 'open': '05:00'},
#    'Thursday': {'close': '23:00', 'open': '05:00'},
#    'Sunday': {'close': '23:00', 'open': '06:00'},
#    'Saturday': {'close': '00:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['Burgers', 'Fast Food', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': "McDonald's",
#   'neighborhoods': [],
#   'longitude': -89.5250779,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.090653,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Alcohol': 'none',
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Has TV': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Attire': 'casual',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '9874O-3GjXPotxYKNNAz5Q',
#   'full_address': '1009 N Gammon Rd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '18:00', 'open': '08:00'},
#    'Tuesday': {'close': '18:00', 'open': '08:00'},
#    'Friday': {'close': '18:00', 'open': '08:00'},
#    'Wednesday': {'close': '18:00', 'open': '08:00'},
#    'Thursday': {'close': '18:00', 'open': '08:00'},
#    'Saturday': {'close': '12:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Veterinarians', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'All Pets Veterinary Clinic',
#   'neighborhoods': [],
#   'longitude': -89.5022518,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.082611,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'naqkXvhoqljvA7kuo15gEw',
#   'full_address': '8212 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 8,
#   'name': 'Fairfield Inn & Suites Madison West',
#   'neighborhoods': [],
#   'longitude': -89.5233883,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.0901268,
#   'attributes': {'Dogs Allowed': False,
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'xbJ9tdGbcVJIUkNgHSCwZQ',
#   'full_address': '1914 Aurora St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Bars', 'Nightlife', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 10,
#   'name': 'Hody Bar & Grill',
#   'neighborhoods': [],
#   'longitude': -89.5128222,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.095696,
#   'attributes': {'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Good For Dancing': True,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Has TV': True,
#    'Smoking': 'no',
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': False,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'koRLvzIl-4fCybOIdk56jA',
#   'full_address': '7464 Hubbard Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '23:00', 'open': '17:00'},
#    'Tuesday': {'close': '23:00', 'open': '17:00'},
#    'Friday': {'close': '23:00', 'open': '17:00'},
#    'Wednesday': {'close': '23:00', 'open': '17:00'},
#    'Thursday': {'close': '23:00', 'open': '17:00'},
#    'Saturday': {'close': '23:00', 'open': '17:00'}},
#   'open': True,
#   'categories': ['Cajun/Creole', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 56,
#   'name': "Louisianne's Etc",
#   'neighborhoods': [],
#   'longitude': -89.5110574,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0955526,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Good for Kids': False,
#    'Takes Reservations': True,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': True,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': False,
#    'Good For Groups': True,
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'ckLRf3lYn9DxmNxd-mu2yA',
#   'full_address': '1313 John Q Hammons Dr\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 35,
#   'name': 'Marriott-Madison West',
#   'neighborhoods': [],
#   'longitude': -89.523172,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.087887,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'paid',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'very_loud',
#    'Takes Reservations': True,
#    'Has TV': True,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'Bznf9AaGgdsLI01H_ifrUA',
#   'full_address': '7625 Lisa Ln\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Active Life', 'Amateur Sports Teams'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Bowling Green Rec Center',
#   'neighborhoods': [],
#   'longitude': -89.511857,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1083799,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'YaaQx4qt1f36iFT4TWivAw',
#   'full_address': '7610 Donna Dr\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:30', 'open': '07:00'},
#    'Tuesday': {'close': '17:30', 'open': '07:00'},
#    'Friday': {'close': '17:30', 'open': '07:00'},
#    'Wednesday': {'close': '17:30', 'open': '07:00'},
#    'Thursday': {'close': '17:30', 'open': '07:00'},
#    'Saturday': {'close': '17:00', 'open': '07:30'}},
#   'open': True,
#   'categories': ['Bakeries', 'Food'],
#   'city': 'Middleton',
#   'review_count': 14,
#   'name': "Clasen's European Bakery",
#   'neighborhoods': [],
#   'longitude': -89.51178,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1060972,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'MBQc_jlZ3nlMOZy7SUM_5Q',
#   'full_address': '1801 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 12,
#   'name': 'Hilton Garden Inn Madison West/Middleton',
#   'neighborhoods': [],
#   'longitude': -89.525484,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.092882,
#   'attributes': {'Dogs Allowed': False,
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'cruBFtsFaBuhX_I72uU8pA',
#   'full_address': '6615 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '22:00', 'open': '10:00'},
#    'Tuesday': {'close': '22:00', 'open': '10:00'},
#    'Friday': {'close': '22:00', 'open': '10:00'},
#    'Wednesday': {'close': '22:00', 'open': '10:00'},
#    'Thursday': {'close': '22:00', 'open': '10:00'},
#    'Sunday': {'close': '22:00', 'open': '10:00'},
#    'Saturday': {'close': '22:00', 'open': '10:00'}},
#   'open': True,
#   'categories': ['Pizza', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Papa John's Pizza",
#   'neighborhoods': [],
#   'longitude': -89.4949208,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 43.0955472,
#   'attributes': {'Take-out': True,
#    'Alcohol': 'none',
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Price Range': 2,
#    'Good For Groups': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'X47o6R2rWiqGqvBtC7VS3Q',
#   'full_address': '2227 Parmenter St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '14:00', 'open': '06:30'},
#    'Tuesday': {'close': '14:00', 'open': '06:30'},
#    'Friday': {'close': '13:30', 'open': '06:30'},
#    'Wednesday': {'close': '14:00', 'open': '06:30'},
#    'Thursday': {'close': '14:00', 'open': '06:30'},
#    'Sunday': {'close': '12:00', 'open': '07:00'},
#    'Saturday': {'close': '12:00', 'open': '06:30'}},
#   'open': True,
#   'categories': ['Breakfast & Brunch', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 19,
#   'name': 'Three Sisters Old Town Inn',
#   'neighborhoods': [],
#   'longitude': -89.511243,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0999335,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': True},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': True,
#    'Accepts Credit Cards': False,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '_tnYCShXuDlXjNVNctTkCA',
#   'full_address': '6323 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:00', 'open': '08:00'},
#    'Tuesday': {'close': '17:00', 'open': '08:00'},
#    'Friday': {'close': '17:00', 'open': '08:00'},
#    'Wednesday': {'close': '17:00', 'open': '08:00'},
#    'Thursday': {'close': '17:00', 'open': '08:00'},
#    'Saturday': {'close': '14:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Barbers', 'Beauty & Spas'],
#   'city': 'Middleton',
#   'review_count': 11,
#   'name': "Dick & Arnie's Barber Shop",
#   'neighborhoods': [],
#   'longitude': -89.4904366,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.0926846,
#   'attributes': {'By Appointment Only': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': False,
#    'Wheelchair Accessible': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'elBgDynz6UPoSqQgxiggJw',
#   'full_address': '3201 Glacier Ridge Rd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
# ...
#    'Saturday': {'close': '17:30', 'open': '08:30'}},
#   'open': False,
#   'categories': ['Car Wash', 'Automotive'],
#   'city': 'Phoenix',
#   'review_count': 16,
#   'name': 'Arcadia Car Wash',
#   'neighborhoods': [],
#   'longitude': -111.9867688,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4948739,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'VxnV1uMZURUQMNUaPdB8QA',
#   'full_address': '4515 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '23:00', 'open': '08:00'},
#    'Tuesday': {'close': '23:00', 'open': '08:00'},
#    'Friday': {'close': '23:00', 'open': '08:00'},
#    'Wednesday': {'close': '23:00', 'open': '08:00'},
#    'Thursday': {'close': '23:00', 'open': '08:00'},
#    'Sunday': {'close': '22:00', 'open': '08:00'},
#    'Saturday': {'close': '23:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Department Stores', 'Fashion', 'Shopping', 'Drugstores'],
#   'city': 'Phoenix',
#   'review_count': 36,
#   'name': 'Target',
#   'neighborhoods': [],
#   'longitude': -111.9850859,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4801135,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'JksZiHb_Vj1tYRTpuTg-uQ',
#   'full_address': '4519 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '21:00', 'open': '08:00'},
#    'Tuesday': {'close': '21:00', 'open': '08:00'},
#    'Friday': {'close': '21:00', 'open': '08:00'},
#    'Wednesday': {'close': '21:00', 'open': '08:00'},
#    'Thursday': {'close': '21:00', 'open': '08:00'},
#    'Sunday': {'close': '18:00', 'open': '10:00'},
#    'Saturday': {'close': '19:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Shopping', 'Office Equipment'],
#   'city': 'Phoenix',
#   'review_count': 7,
#   'name': 'Office Max',
#   'neighborhoods': [],
#   'longitude': -111.9854985,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4800765,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'SDwYQ6eSu1htn8vHWv128g',
#   'full_address': '3939 E Campbell Ave\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '23:00', 'open': '11:00'},
#    'Tuesday': {'close': '23:00', 'open': '11:00'},
#    'Friday': {'close': '00:00', 'open': '11:00'},
#    'Wednesday': {'close': '23:00', 'open': '11:00'},
#    'Thursday': {'close': '23:00', 'open': '11:00'},
#    'Sunday': {'close': '22:00', 'open': '09:00'},
#    'Saturday': {'close': '00:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Wine Bars', 'Bars', 'Restaurants', 'Nightlife', 'Italian'],
#   'city': 'Phoenix',
#   'review_count': 921,
#   'name': 'Postino Arcadia',
#   'neighborhoods': [],
#   'longitude': -111.996292,
#   'state': 'AZ',
#   'stars': 4.5,
#   'latitude': 33.502191,
#   'attributes': {'Alcohol': 'beer_and_wine',
#    'Open 24 Hours': False,
#    'Noise Level': 'average',
#    'Music': {'dj': False,
#     'background_music': True,
#     'jukebox': False,
#     'live': False,
#     'video': False,
#     'karaoke': False},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': True,
#     'upscale': False,
#     'casual': False},
#    'Good for Kids': False,
#    'Wheelchair Accessible': True,
#    'Delivery': False,
#    'Good For Dancing': False,
#    'BYOB': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'BYOB/Corkage': 'no',
#    'Take-out': True,
#    'Price Range': 2,
#    'Corkage': False,
#    'Happy Hour': True,
#    'Outdoor Seating': True,
#    'Takes Reservations': True,
#    'Waiter Service': True,
#    'Wi-Fi': 'no',
#    'Caters': True,
#    'Dietary Restrictions': {'dairy-free': False,
#     'gluten-free': False,
#     'vegan': True,
#     'kosher': False,
#     'halal': False,
#     'soy-free': False,
#     'vegetarian': True},
#    'Order at Counter': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': True},
#    'Has TV': False,
#    'Good For Kids': False,
#    'Good For Groups': True},
#   'type': 'business'},
#  {'business_id': '7UTlEVHU5v2xBLdkGghyzQ',
#   'full_address': '3222 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': False,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 21,
#   'name': "Chuy's Mesquite Broiler",
#   'neighborhoods': [],
#   'longitude': -112.0119403,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.4953259,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Takes Reservations': False,
#    'BYOB/Corkage': 'no',
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '5WQhLNpG6xZryVCla4gMRA',
#   'full_address': '4505 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '00:00', 'open': '06:00'},
#    'Tuesday': {'close': '00:00', 'open': '06:00'},
#    'Friday': {'close': '00:00', 'open': '06:00'},
#    'Wednesday': {'close': '00:00', 'open': '06:00'},
#    'Thursday': {'close': '00:00', 'open': '06:00'},
#    'Sunday': {'close': '00:00', 'open': '06:00'},
#    'Saturday': {'close': '00:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['Grocery',
#    'American (Traditional)',
#    'Shopping',
#    'Drugstores',
#    'Food',
#    'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 26,
#   'name': "Fry's Food Store",
#   'neighborhoods': [],
#   'longitude': -111.984771,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.479131,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'free',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': True,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Has TV': True,
#    'BYOB/Corkage': 'yes_corkage',
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Corkage': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'r-EVE9HYaJoaaK82Z7o3OQ',
#   'full_address': '5130 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Groomers', 'Pet Services', 'Pets'],
#   'city': 'Phoenix',
#   'review_count': 5,
#   'name': 'Ingleside Grooming',
#   'neighborhoods': [],
#   'longitude': -111.9702112,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4801284,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'yJr24Yy1K6bt2G9fX3_zPA',
#   'full_address': '4225 E Camelback Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '21:30', 'open': '11:00'},
#    'Tuesday': {'close': '21:30', 'open': '11:00'},
#    'Friday': {'close': '22:00', 'open': '11:00'},
#    'Wednesday': {'close': '21:30', 'open': '11:00'},
#    'Thursday': {'close': '21:30', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '22:00', 'open': '11:00'}},
#   'open': False,
#   'categories': ['Cuban', 'Caribbean', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 188,
#   'name': 'Havana Cafe',
#   'neighborhoods': [],
#   'longitude': -111.9885861,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.5092093,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': True,
#    'Noise Level': 'average',
#    'Good for Kids': False,
#    'Takes Reservations': True,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Has TV': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Order at Counter': False,
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': False,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'Qj2h9JA59E_J-ogfdjx7Lg',
#   'full_address': '3623 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': [],
#   'city': 'Phoenix',
#   'review_count': 4,
#   'name': 'Famous Wings',
#   'neighborhoods': [],
#   'longitude': -112.0031664,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.495169,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'wdEnI9WTLHiqSCH1RdJ40w',
#   'full_address': '4732 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 16,
#   'name': 'Los Armandos',
#   'neighborhoods': [],
#   'longitude': -111.978627,
#   'state': 'AZ',
#   'stars': 3.0,
#   'latitude': 33.480391,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'qz4ZOcv-840UjfCEYI4qZg',
#   'full_address': '4829 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '00:00', 'open': '15:30'},
#    'Tuesday': {'close': '00:00', 'open': '15:30'},
#    'Friday': {'close': '02:00', 'open': '15:30'},
#    'Wednesday': {'close': '00:00', 'open': '15:30'},
#    'Thursday': {'close': '00:00', 'open': '15:30'},
#    'Sunday': {'close': '17:30', 'open': '11:00'},
#    'Saturday': {'close': '02:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Burgers',
#    'Bars',
#    'American (Traditional)',
#    'Nightlife',
#    'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 62,
#   'name': "Jt's Bar & Grill",
#   'neighborhoods': [],
#   'longitude': -111.976613,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.494204,
#   'attributes': {'Drive-Thru': False,
#    'Alcohol': 'full_bar',
#    'Noise Level': 'average',
#    'Music': {'dj': False,
#     'background_music': False,
#     'jukebox': True,
#     'live': False,
#     'video': False,
#     'karaoke': False},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': True,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Good for Kids': False,
#    'Wheelchair Accessible': True,
#    'Good For Dancing': False,
#    'Delivery': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'BYOB/Corkage': 'no',
#    'Take-out': True,
#    'Price Range': 1,
#    'Happy Hour': False,
#    'Outdoor Seating': True,
#    'Takes Reservations': False,
#    'Waiter Service': True,
#    'Wi-Fi': 'free',
#    'Caters': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'breakfast': False,
#     'brunch': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Good For Groups': False},
#   'type': 'business'},
#  {'business_id': '015GCpe-tMj1En4NORROzA',
#   'full_address': '4801 E Indian School Rd\nSte 6\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '19:00', 'open': '07:00'},
#    'Tuesday': {'close': '19:00', 'open': '07:00'},
#    'Friday': {'close': '19:00', 'open': '07:00'},
#    'Wednesday': {'close': '19:00', 'open': '07:00'},
#    'Thursday': {'close': '19:00', 'open': '07:00'},
#    'Saturday': {'close': '18:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Local Services', 'Dry Cleaning & Laundry'],
#   'city': 'Phoenix',
#   'review_count': 14,
#   'name': 'Elite Cleaners',
#   'neighborhoods': [],
#   'longitude': -111.977756,
#   'state': 'AZ',
#   'stars': 4.5,
#   'latitude': 33.49413,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'no',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'AJONCMi8dnGWAkD-86FK5A',
#   'full_address': '4280 E Indian School Rd\nSte 107\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '18:00', 'open': '09:00'},
#    'Tuesday': {'close': '18:00', 'open': '09:00'},
#    'Friday': {'close': '18:00', 'open': '09:00'},
#    'Wednesday': {'close': '18:00', 'open': '09:00'},
#    'Thursday': {'close': '18:00', 'open': '09:00'},
#    'Sunday': {'close': '17:00', 'open': '11:00'},
#    'Saturday': {'close': '17:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Shopping',
#    'Optometrists',
#    'Health & Medical',
#    'Eyewear & Opticians'],
#   'city': 'Phoenix',
#   'review_count': 11,
#   'name': 'Nationwide Vision Centers',
#   'neighborhoods': [],
#   'longitude': -111.9891177,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.495074,
#   'attributes': {'By Appointment Only': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'FRDZ59oRvUSs4gf-itOCBg',
#   'full_address': '4343 E Camelback Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 3,
#   'name': 'Jack in the Box',
#   'neighborhoods': [],
#   'longitude': -111.9875851,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.5091326,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  ...]

# %%
yelp_df = pd.DataFrame(yelp_data)
yelp_df.head()
# Out:
#               business_id                                       full_address  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1  JwUE5GmEO-sH1FuwJgKBlQ            6162 US Highway 51\nDe Forest, WI 53532
# 2  uGykseHzyS5xAMWoN6YUqA                505 W North St\nDe Forest, WI 53532
# 3  LRKJF43s9-3jG9Lgx4zODg              4910 County Rd V\nDe Forest, WI 53532
# 4  RgDg-k9S5YD_BaxMckifkg                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours  open  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  True
# 1                                                 {}  True
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  True
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  True
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  True
#
#                                           categories       city  review_count  \
# 0                        [Doctors, Health & Medical]    Phoenix             7
# 1                                      [Restaurants]  De Forest            26
# 2              [American (Traditional), Restaurants]  De Forest            16
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest             7
# 4                             [Chinese, Restaurants]  De Forest             3
#
#                           name neighborhoods   longitude state  stars  \
# 0            Eric Goldberg, MD            [] -111.983758    AZ    3.5
# 1         Pine Cone Restaurant            []  -89.335844    WI    4.0
# 2   Deforest Family Restaurant            []  -89.353437    WI    4.0
# 3                     Culver's            []  -89.374983    WI    4.5
# 4  Chang Jiang Chinese Kitchen            []  -89.343722    WI    4.0
#
#     latitude                                         attributes      type
# 0  33.499313                      {'By Appointment Only': True}  business
# 1  43.238893  {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 2  43.252267  {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 3  43.251045  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  business
# 4  43.240875  {'Take-out': True, 'Has TV': False, 'Outdoor S...  business

# %% [markdown]
# ## Pandas DataFrame and Series
#
# The Pandas DataFrame is a highly structured object. Each row corresponds with some physical entity or event. We think of all of the information in a given row as referring to one object (e.g. a business). Each column contains one type of data, both semantically (e.g. names, counts of reviews, star ratings) and syntactically.

# %%
yelp_df['city'].head()
# Out:
# 0      Phoenix
# 1    De Forest
# 2    De Forest
# 3    De Forest
# 4    De Forest
# Name: city, dtype: object

# %% [markdown]
# We can reference the columns by name, like we would with a `dict`.

# %%
type(yelp_df['city'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# An individual column is a Pandas `Series`. A `Series` has a `name` and a `dtype` (similar to a NumPy array). A `DataFrame` is essentially a `dict` of `Series` objects. The `Series` has an `index` attribute, which label the rows. The index is essentially a set of keys for referencing the rows. We can have an index composed of numbers, strings, timestamps, or any hashable Python object. The index will also have homogeneous type.

# %%
yelp_df['city'].index
# Out:
# RangeIndex(start=0, stop=37938, step=1)

# %% [markdown]
# The `DataFrame` has an `index` given by the union of indices of its constituent `Series` (we'll explore this later in more detail). Since a `DataFrame` is a `dict` of `Series`, we can select a column and then a row using square bracket notation, but not the reverse (however, the `loc` method works around this).

# %%
# this works
yelp_df['city'][100]
# Out:
# 'Madison'

# %%
# %%expect_exception KeyError
#
# # this doesn't
# yelp_df[100]['city']
# Out:
# UsageError: Cell magic `%%expect_exception` not found.

# %%
yelp_df.loc[100, 'city']
# Out:
# 'Madison'

# %% [markdown]
# Understanding the underlying structure of the `DataFrame` object as a `dict` of `Series` will help you avoid errors and help you think about how the `DataFrame` should behave when we begin doing more complicated analysis.
#
# We can _aggregate_ data in a `DataFrame` using methods like `mean`, `sum`, `count`, and `std`. To view a collection of summary statistics for each column we can use the `describe` method.

# %%
yelp_df.describe()
# Out:
#        review_count     longitude         stars      latitude
# count  37938.000000  37938.000000  37938.000000  37938.000000
# mean      29.300648   -104.097172      3.672914     36.530288
# std       92.893064     28.365375      0.888730      5.822588
# min        3.000000   -115.369725      1.000000     32.876638
# 25%        4.000000   -115.136389      3.000000     33.476739
# 50%        8.000000   -112.068820      3.500000     33.680247
# 75%       21.000000   -111.883274      4.500000     36.141875
# max     4084.000000     -3.050088      5.000000     56.033777

# %% [markdown]
# The utility of a DataFrame comes from its ability to split data into groups, using the `groupby` method, and then perform custom aggregations using the `apply` or `aggregate` method. This process of splitting the data into groups, applying an aggregation, and then collecting the results is [discussed in detail in the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/groupby.html), and is one of the main focuses of this notebook.

# %% [markdown]
# ## DataFrame construction
#
# Since a `DataFrame` is a `dict` of `Series`, the natural way to construct a `DataFrame` is to use a `dict` of `Series`-like objects.

# %%
from string import ascii_letters, digits
import numpy as np
import datetime

# %%
usernames = ['alice36', 'bob_smith', 'eve']

passwords = [''.join(np.random.choice(list(ascii_letters + digits), 8)) for x in range(3)]

creation_dates = [datetime.datetime.now().date() - datetime.timedelta(int(x)) for x in np.random.randint(0, 1500, 3)]

# %%
data_df = pd.DataFrame({'username': usernames, 'password': passwords, 'date-created': pd.to_datetime(creation_dates)})
data_df
# Out:
#     username  password date-created
# 0    alice36  SMHmfivR   2017-07-25
# 1  bob_smith  WCgn0p4K   2017-06-26
# 2        eve  6xdBgH6V   2017-04-22

# %%
name = ['ope', 'gopola', 'polity', 'treasure', 'june', 
       'hassan', 'ijuso', 'kelechi', 'michael', 'bench']

passwords = [''.join(np.random.choice(list(ascii_letters + digits), 8)) for x in range(10)]

matriculation_number = [''.join(np.random.choice(list('u2012' + digits), 8)) for x in range(10)]

creation_date = [datetime.datetime.now().date() - datetime.timedelta(int(x)) for x in np.random.randint(0, 1500, 10)]

# %%
student_df = pd.DataFrame({'username': name, 'password': passwords, 'ID_number': matriculation_number,
                          'date-created': pd.to_datetime(creation_dates)})
student_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-bcc86f548af8> in <module>
# ----> 1 student_df = pd.DataFrame({'username': name, 'password': passwords, 'ID_number': matriculation_number,
#       2                           'date-created': pd.to_datetime(creation_dates)})
#       3 student_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# The `DataFrame` is also closely related to the NumPy `ndarray`.

# %%
data_df.dtypes
# Out:
# username                object
# password                object
# date-created    datetime64[ns]
# dtype: object

# %%
random_data = np.random.random((4,3))
random_data
# Out:
# array([[0.7367227 , 0.75057286, 0.28368132],
#        [0.58628538, 0.99521432, 0.6891033 ],
#        [0.85096993, 0.85365049, 0.09632721],
#        [0.37814644, 0.50352112, 0.93895029]])

# %%
data_df_random = pd.DataFrame(random_data, columns=['a', 'b', 'c'])
data_df_random
# Out:
#           a         b         c
# 0  0.736723  0.750573  0.283681
# 1  0.586285  0.995214  0.689103
# 2  0.850970  0.853650  0.096327
# 3  0.378146  0.503521  0.938950

# %% [markdown]
# To add a new column or row, we simply use `dict`-like assignment.

# %%
emails = ['alice.chan@gmail.com', 'bwsmith1983@gmail.com', 'fakemail123@yahoo.com']
data_df['email'] = emails
data_df
# Out:
#     username  password date-created                  email
# 0    alice36  SMHmfivR   2017-07-25   alice.chan@gmail.com
# 1  bob_smith  WCgn0p4K   2017-06-26  bwsmith1983@gmail.com
# 2        eve  6xdBgH6V   2017-04-22  fakemail123@yahoo.com

# %%
# loc references index value, NOT position
# for position use iloc
data_df.loc[3] = ['2015-01-29', '38uzFJ1n', 'melvintherobot', 'moviesrgood@moviesrgood.com']
data_df
# Out:
#      username  password         date-created                        email
# 0     alice36  SMHmfivR  2017-07-25 00:00:00         alice.chan@gmail.com
# 1   bob_smith  WCgn0p4K  2017-06-26 00:00:00        bwsmith1983@gmail.com
# 2         eve  6xdBgH6V  2017-04-22 00:00:00        fakemail123@yahoo.com
# 3  2015-01-29  38uzFJ1n       melvintherobot  moviesrgood@moviesrgood.com

# %%
data_df.loc[5] = ['grandies', 'ARyhre86', '2018-09-20', 'grnadvealley@gmail.com']
data_df
# Out:
#      username  password         date-created                        email
# 0     alice36  SMHmfivR  2017-07-25 00:00:00         alice.chan@gmail.com
# 1   bob_smith  WCgn0p4K  2017-06-26 00:00:00        bwsmith1983@gmail.com
# 2         eve  6xdBgH6V  2017-04-22 00:00:00        fakemail123@yahoo.com
# 3  2015-01-29  38uzFJ1n       melvintherobot  moviesrgood@moviesrgood.com
# 5    grandies  ARyhre86           2018-09-20       grnadvealley@gmail.com

# %% [markdown]
# We can also drop columns and rows.

# %%
data_df.drop(5)
# Out:
#      username  password         date-created                        email
# 0     alice36  SMHmfivR  2017-07-25 00:00:00         alice.chan@gmail.com
# 1   bob_smith  WCgn0p4K  2017-06-26 00:00:00        bwsmith1983@gmail.com
# 2         eve  6xdBgH6V  2017-04-22 00:00:00        fakemail123@yahoo.com
# 3  2015-01-29  38uzFJ1n       melvintherobot  moviesrgood@moviesrgood.com

# %%
# to drop a column, need axis=1
data_df.drop('email', axis=1)
# Out:
#      username  password         date-created
# 0     alice36  SMHmfivR  2017-07-25 00:00:00
# 1   bob_smith  WCgn0p4K  2017-06-26 00:00:00
# 2         eve  6xdBgH6V  2017-04-22 00:00:00
# 3  2015-01-29  38uzFJ1n       melvintherobot
# 5    grandies  ARyhre86           2018-09-20

# %%
# to drop multiple columns, need axis=1

# %% [markdown]
# Notice when we dropped the `'email'` column, the row at index 3 was in the `DataFrame`, even though we just dropped it! Most operations in Pandas return a _copy_ of the `DataFrame`, rather than modifying the `DataFrame` object itself. Therefore, in order to permanently alter the `DataFrame`, we either need to reassign the `df` variable, or use the `inplace` keyword.

# %%
data_df.drop(5, inplace=True)
data_df
# Out:
#      username  password         date-created                        email
# 0     alice36  SMHmfivR  2017-07-25 00:00:00         alice.chan@gmail.com
# 1   bob_smith  WCgn0p4K  2017-06-26 00:00:00        bwsmith1983@gmail.com
# 2         eve  6xdBgH6V  2017-04-22 00:00:00        fakemail123@yahoo.com
# 3  2015-01-29  38uzFJ1n       melvintherobot  moviesrgood@moviesrgood.com

# %% [markdown]
# Since the `index` and column names are important for interacting with data in the DataFrame, we should make sure to set them to useful values. We can do this during construction or after.

# %%
data_df = pd.DataFrame({'email': emails, 'password': passwords, 'date-created': pd.to_datetime(creation_dates)}, index=usernames)
data_df.index.name = 'users' 
# it can be helpful to give the index a name
data_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-968b2c9b65eb> in <module>
# ----> 1 data_df = pd.DataFrame({'email': emails, 'password': passwords, 'date-created': pd.to_datetime(creation_dates)}, index=usernames)
#       2 data_df.index.name = 'users'
#       3 # it can be helpful to give the index a name
#       4 data_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      72     axes = [ensure_index(columns), index]
#      73
# ---> 74     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      75
#      76
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1673         return mgr
#    1674     except ValueError as e:
# -> 1675         construction_error(len(arrays), arrays[0].shape, axes, e)
#    1676
#    1677
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1689
#    1690     if passed == implied and e is not None:
# -> 1691         raise e
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1668
#    1669     try:
# -> 1670         blocks = form_blocks(arrays, names, axes)
#    1671         mgr = BlockManager(blocks, axes)
#    1672         mgr._consolidate_inplace()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in form_blocks(arrays, names, axes)
#    1755
#    1756     if len(items_dict["ObjectBlock"]) > 0:
# -> 1757         object_blocks = _simple_blockify(items_dict["ObjectBlock"], np.object_)
#    1758         blocks.extend(object_blocks)
#    1759
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _simple_blockify(tuples, dtype)
#    1799     not None, coerce to this dtype
#    1800     """
# -> 1801     values, placement = _stack_arrays(tuples, dtype)
#    1802
#    1803     # TODO: CHECK DTYPE?
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
#    1848     stacked = np.empty(shape, dtype=dtype)
#    1849     for i, arr in enumerate(arrays):
# -> 1850         stacked[i] = _asarray_compat(arr)
#    1851
#    1852     return stacked, placement
#
# ValueError: could not broadcast input array from shape (10) into shape (3)

# %%
# alternatively
data_df= pd.DataFrame(list(zip(usernames, emails, passwords, creation_dates)))
data_df
# Out:
#            0                      1         2           3
# 0    alice36   alice.chan@gmail.com  XhRvUVeU  2017-07-25
# 1  bob_smith  bwsmith1983@gmail.com  Ryqy8rF1  2017-06-26
# 2        eve  fakemail123@yahoo.com  yfI8ENqX  2017-04-22

# %%
data_df.columns = ['username', 'email', 'password', 'date-created']
data_df.set_index('username', inplace=True)
data_df
# Out:
#                            email  password date-created
# username
# alice36     alice.chan@gmail.com  XhRvUVeU   2017-07-25
# bob_smith  bwsmith1983@gmail.com  Ryqy8rF1   2017-06-26
# eve        fakemail123@yahoo.com  yfI8ENqX   2017-04-22

# %%
# to reset index to a column
data_df.reset_index(inplace=True)
data_df
# Out:
#     username                  email  password date-created
# 0    alice36   alice.chan@gmail.com  XhRvUVeU   2017-07-25
# 1  bob_smith  bwsmith1983@gmail.com  Ryqy8rF1   2017-06-26
# 2        eve  fakemail123@yahoo.com  yfI8ENqX   2017-04-22

# %% [markdown]
# We can have multiple levels to an index. We'll discover that for some data sets it is necessary to have multiple levels to the index in order to uniquely identify a row.

# %%
data_df.set_index(['username', 'email'])
# Out:
#                                  password date-created
# username  email
# alice36   alice.chan@gmail.com   XhRvUVeU   2017-07-25
# bob_smith bwsmith1983@gmail.com  Ryqy8rF1   2017-06-26
# eve       fakemail123@yahoo.com  yfI8ENqX   2017-04-22

# %%
data_df.set_index(['username', 'email', 'password'])
# Out:
#                                          date-created
# username  email                 password
# alice36   alice.chan@gmail.com  XhRvUVeU   2017-07-25
# bob_smith bwsmith1983@gmail.com Ryqy8rF1   2017-06-26
# eve       fakemail123@yahoo.com yfI8ENqX   2017-04-22

# %% [markdown]
# ### Reading data from file
#
# We can also construct a DataFrame using data stored in a file or received from a website. The data source might be [JSON](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_json.html), [HTML](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html), [CSV](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html#pandas.read_csv), [Excel](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html), [Python pickle](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_pickle.html), or even a [database connection](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql.html). Each format will have its own methods for reading and writing data that take different arguments. The arguments of these methods usually depend on the particular formatting of the file. For example, the values in a CSV might be separate by commas or semi-colons, it might have a header or it might not.
#
# The `read_csv` method has to deal with the most formatting possibilities, so we will explore that method with a few examples. Try to apply these ideas when working with other file formats, but keep in mind that each format and read method is different. Always check [the Pandas documentation](http://pandas.pydata.org/pandas-docs/stable/io.html) when having trouble with reading or writing data.m

# %%
csv = [','.join(map(lambda x: str(x), row)) for row in np.vstack([df.columns, df])]
with open('./data/read_csv_example.csv', 'w') as f:
    [f.write(line + '\n') for line in csv]

# !cat ./data/read_csv_example.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-c864cfb4cd68> in <module>
# ----> 1 csv = [','.join(map(lambda x: str(x), row)) for row in np.vstack([df.columns, df])]
#       2 with open('./data/read_csv_example.csv', 'w') as f:
#       3     [f.write(line + '\n') for line in csv]
#       4
#       5 get_ipython().system('cat ./data/read_csv_example.csv')
#
# NameError: name 'df' is not defined

# %%
pd.read_csv('./data/read_csv_example.csv')
# Out:
#                    email  password date-created
# 0   alice.chan@gmail.com  LBVIzqTj   2019-08-09
# 1  bwsmith1983@gmail.com  OnPk891p   2017-06-21
# 2  fakemail123@yahoo.com  Uw4fArcv   2020-02-12

# %%
# we can also set an index from the data
pd.read_csv('./data/read_csv_example.csv', index_col=0)
# Out:
#                        password date-created
# email
# alice.chan@gmail.com   LBVIzqTj   2019-08-09
# bwsmith1983@gmail.com  OnPk891p   2017-06-21
# fakemail123@yahoo.com  Uw4fArcv   2020-02-12

# %%
# we can also set an index from the data
pd.read_csv('./data/read_csv_example.csv', index_col=1)
# Out:
#                           email date-created
# password
# LBVIzqTj   alice.chan@gmail.com   2019-08-09
# OnPk891p  bwsmith1983@gmail.com   2017-06-21
# Uw4fArcv  fakemail123@yahoo.com   2020-02-12

# %%
# we can also set an index from the data
pd.read_csv('./data/read_csv_example.csv', index_col=2)
# Out:
#                               email  password
# date-created
# 2019-08-09     alice.chan@gmail.com  LBVIzqTj
# 2017-06-21    bwsmith1983@gmail.com  OnPk891p
# 2020-02-12    fakemail123@yahoo.com  Uw4fArcv

# %%
# what if our data had no header?
with open('./data/read_csv_noheader_example.csv', 'w') as f:
    [f.write(line + '\n') for i, line in enumerate(csv) if i != 0]
    
# !cat ./data/read_csv_noheader_example.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-e902b26ce6f0> in <module>
#       1 # what if our data had no header?
#       2 with open('./data/read_csv_noheader_example.csv', 'w') as f:
# ----> 3     [f.write(line + '\n') for i, line in enumerate(csv) if i != 0]
#       4
#       5 get_ipython().system('cat ./data/read_csv_noheader_example.csv')
#
# NameError: name 'csv' is not defined

# %%
pd.read_csv('./data/read_csv_noheader_example.csv', names=['username', 'email', 'password', 'date-created'], header=None)
# Out:
# Empty DataFrame
# Columns: [username, email, password, date-created]
# Index: []

# %%
# what if our data was tab-delimited?
tsv = ['\t'.join(map(lambda x: str(x), row)) for row in np.vstack([df.columns, df])]
with open('./data/read_csv_example.tsv', 'w') as f:
    [f.write(line + '\n') for line in tsv]

# !cat ./data/read_csv_example.tsv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-4453d7279d4e> in <module>
#       1 # what if our data was tab-delimited?
# ----> 2 tsv = ['\t'.join(map(lambda x: str(x), row)) for row in np.vstack([df.columns, df])]
#       3 with open('./data/read_csv_example.tsv', 'w') as f:
#       4     [f.write(line + '\n') for line in tsv]
#       5
#
# NameError: name 'df' is not defined

# %%
pd.read_csv('./data/read_csv_example.tsv', delimiter='\t')
# Out:
#                    email  password date-created
# 0   alice.chan@gmail.com  LBVIzqTj   2019-08-09
# 1  bwsmith1983@gmail.com  OnPk891p   2017-06-21
# 2  fakemail123@yahoo.com  Uw4fArcv   2020-02-12

# %% [markdown]
# Even within a single file format, data can be arranged and formatted in many ways. These have been just a few examples of the kinds of arguments you might need to use with `read_csv` in order to read data into a DataFrame in an organized way.

# %% [markdown]
# ## Filtering DataFrames
#
# One of the powerful analytical tools of the Pandas DataFrame is its syntax for filtering data. Often we'll only want to work with a certain subset of our data based on some criteria. Let's look at our Yelp data for an example.

# %%
yelp_df.head()
# Out:
#               business_id                                       full_address  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1  JwUE5GmEO-sH1FuwJgKBlQ            6162 US Highway 51\nDe Forest, WI 53532
# 2  uGykseHzyS5xAMWoN6YUqA                505 W North St\nDe Forest, WI 53532
# 3  LRKJF43s9-3jG9Lgx4zODg              4910 County Rd V\nDe Forest, WI 53532
# 4  RgDg-k9S5YD_BaxMckifkg                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours  open  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  True
# 1                                                 {}  True
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  True
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  True
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  True
#
#                                           categories       city  review_count  \
# 0                        [Doctors, Health & Medical]    Phoenix             7
# 1                                      [Restaurants]  De Forest            26
# 2              [American (Traditional), Restaurants]  De Forest            16
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest             7
# 4                             [Chinese, Restaurants]  De Forest             3
#
#                           name neighborhoods   longitude state  stars  \
# 0            Eric Goldberg, MD            [] -111.983758    AZ    3.5
# 1         Pine Cone Restaurant            []  -89.335844    WI    4.0
# 2   Deforest Family Restaurant            []  -89.353437    WI    4.0
# 3                     Culver's            []  -89.374983    WI    4.5
# 4  Chang Jiang Chinese Kitchen            []  -89.343722    WI    4.0
#
#     latitude                                         attributes      type
# 0  33.499313                      {'By Appointment Only': True}  business
# 1  43.238893  {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 2  43.252267  {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 3  43.251045  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  business
# 4  43.240875  {'Take-out': True, 'Has TV': False, 'Outdoor S...  business

# %% [markdown]
# We see the Yelp data set has a `'state'` column. If we are only interested in businesses in Arizona (AZ), we can filter the DataFrame and select only that data.

# %%
az_yelp_df = yelp_df[yelp_df['state'] == 'AZ']
az_yelp_df.head()
# Out:
#                 business_id  \
# 0    vcNAWiLM4dR7D2nwwJ7nCA
# 297  x5Mv61CnZLohZWxfCVCPTQ
# 298  2ZnCITVa0abGce4gZ6RhIw
# 299  EmzaQR5hQlF0WIl24NxAZA
# 300  SiwN7f0N4bs4ZtPc4yPgiA
#
#                                           full_address  \
# 0    4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 297              2819 N Central Ave\nPhoenix, AZ 85004
# 298              1850 N Central Ave\nPhoenix, AZ 85004
# 299             132 E Washington St\nPhoenix, AZ 85004
# 300               710 N Central Ave\nPhoenix, AZ 85004
#
#                                                  hours  open  \
# 0    {'Tuesday': {'close': '17:00', 'open': '08:00'...  True
# 297                                                 {}  True
# 298                                                 {}  True
# 299  {'Sunday': {'close': '02:00', 'open': '21:00'}...  True
# 300                                                 {}  True
#
#                                             categories     city  review_count  \
# 0                          [Doctors, Health & Medical]  Phoenix             7
# 297    [Sandwiches, Pizza, Chicken Wings, Restaurants]  Phoenix            12
# 298          [American (New), Sandwiches, Restaurants]  Phoenix             5
# 299  [American (New), Nightlife, Dance Clubs, Resta...  Phoenix            20
# 300                           [Nightlife, Dance Clubs]  Phoenix            15
#
#                        name neighborhoods   longitude state  stars   latitude  \
# 0         Eric Goldberg, MD            [] -111.983758    AZ    3.5  33.499313
# 297          Domino's Pizza            [] -112.073418    AZ    2.5  33.479542
# 298  Viad Tower Restaurants            [] -112.074315    AZ    3.5  33.468988
# 299              Sky Lounge            [] -112.071702    AZ    2.5  33.448399
# 300                 Palazzo            [] -112.074225    AZ    2.5  33.456068
#
#                                             attributes      type
# 0                        {'By Appointment Only': True}  business
# 297  {'Take-out': True, 'Wi-Fi': 'no', 'Alcohol': '...  business
# 298  {'Take-out': True, 'Noise Level': 'quiet', 'De...  business
# 299  {'Alcohol': 'full_bar', 'Price Range': 1, 'Noi...  business
# 300  {'Price Range': 2, 'Alcohol': 'full_bar', 'Goo...  business

# %% [markdown]
# We can combine criteria using logic. What if we're only interested in businesses with more than 10 reviews in Arizona

# %%
yelp_df[(yelp_df['state'] == 'AZ') & (yelp_df['review_count'] > 10)].head()
# Out:
#                 business_id                            full_address  \
# 297  x5Mv61CnZLohZWxfCVCPTQ   2819 N Central Ave\nPhoenix, AZ 85004
# 299  EmzaQR5hQlF0WIl24NxAZA  132 E Washington St\nPhoenix, AZ 85004
# 300  SiwN7f0N4bs4ZtPc4yPgiA    710 N Central Ave\nPhoenix, AZ 85004
# 301  M-MFa0YErVBbFW2IJhGJmw   386 E Virginia Ave\nPhoenix, AZ 85004
# 302  KPoTixdjoJxSqRSEApSAGg   2631 N Central Ave\nPhoenix, AZ 85004
#
#                                                  hours  open  \
# 297                                                 {}  True
# 299  {'Sunday': {'close': '02:00', 'open': '21:00'}...  True
# 300                                                 {}  True
# 301  {'Tuesday': {'close': '18:00', 'open': '07:30'...  True
# 302  {'Monday': {'close': '21:00', 'open': '11:00'}...  True
#
#                                             categories     city  review_count  \
# 297    [Sandwiches, Pizza, Chicken Wings, Restaurants]  Phoenix            12
# 299  [American (New), Nightlife, Dance Clubs, Resta...  Phoenix            20
# 300                           [Nightlife, Dance Clubs]  Phoenix            15
# 301  [Auto Repair, Automotive, Tires, Oil Change St...  Phoenix            28
# 302                                [Thai, Restaurants]  Phoenix           281
#
#                       name neighborhoods   longitude state  stars   latitude  \
# 297         Domino's Pizza            [] -112.073418    AZ    2.5  33.479542
# 299             Sky Lounge            [] -112.071702    AZ    2.5  33.448399
# 300                Palazzo            [] -112.074225    AZ    2.5  33.456068
# 301  Virginia Auto Service            [] -112.065806    AZ    4.0  33.476784
# 302           Wild Thaiger            [] -112.073524    AZ    4.0  33.477934
#
#                                             attributes      type
# 297  {'Take-out': True, 'Wi-Fi': 'no', 'Alcohol': '...  business
# 299  {'Alcohol': 'full_bar', 'Price Range': 1, 'Noi...  business
# 300  {'Price Range': 2, 'Alcohol': 'full_bar', 'Goo...  business
# 301                                                 {}  business
# 302  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  business

# %% [markdown]
# How does this filtering work?
#
# When we write `yelp_df['state'] == 'AZ'`, Pandas selects the `'state'` column and checks whether each row is `'AZ'`. If so, that row is marked `True`, and if not, it is marked `False`. This is how we would normally expect a conditional to work, only now applied to an entire Pandas `Series`. We end up with a Pandas `Series` of Boolean variables.

# %%
(yelp_df['state'] == 'AZ').head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: state, dtype: bool

# %% [markdown]
# We can use a `Series` (or any similar object) of Boolean variables to index the DataFrame.

# %%
data_df
# Out:
#     username                  email  password date-created
# 0    alice36   alice.chan@gmail.com  XhRvUVeU   2017-07-25
# 1  bob_smith  bwsmith1983@gmail.com  Ryqy8rF1   2017-06-26
# 2        eve  fakemail123@yahoo.com  yfI8ENqX   2017-04-22

# %%
data_df[[True, False, True]]
# Out:
#   username                  email  password date-created
# 0  alice36   alice.chan@gmail.com  XhRvUVeU   2017-07-25
# 2      eve  fakemail123@yahoo.com  yfI8ENqX   2017-04-22

# %% [markdown]
# This let's us filter a DataFrame using idiomatic logical expressions like `yelp_df['review_count'] > 10`.
#
# As another example, let's consider the `'open'` column, which is a `True`/`False` flag for whether a business is open. This is also a Boolean Pandas `Series`, so we can just use it directly.

# %%
# the open businesses
yelp_df[yelp_df['open']].head()
# Out:
#               business_id                                       full_address  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1  JwUE5GmEO-sH1FuwJgKBlQ            6162 US Highway 51\nDe Forest, WI 53532
# 2  uGykseHzyS5xAMWoN6YUqA                505 W North St\nDe Forest, WI 53532
# 3  LRKJF43s9-3jG9Lgx4zODg              4910 County Rd V\nDe Forest, WI 53532
# 4  RgDg-k9S5YD_BaxMckifkg                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours  open  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  True
# 1                                                 {}  True
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  True
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  True
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  True
#
#                                           categories       city  review_count  \
# 0                        [Doctors, Health & Medical]    Phoenix             7
# 1                                      [Restaurants]  De Forest            26
# 2              [American (Traditional), Restaurants]  De Forest            16
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest             7
# 4                             [Chinese, Restaurants]  De Forest             3
#
#                           name neighborhoods   longitude state  stars  \
# 0            Eric Goldberg, MD            [] -111.983758    AZ    3.5
# 1         Pine Cone Restaurant            []  -89.335844    WI    4.0
# 2   Deforest Family Restaurant            []  -89.353437    WI    4.0
# 3                     Culver's            []  -89.374983    WI    4.5
# 4  Chang Jiang Chinese Kitchen            []  -89.343722    WI    4.0
#
#     latitude                                         attributes      type
# 0  33.499313                      {'By Appointment Only': True}  business
# 1  43.238893  {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 2  43.252267  {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 3  43.251045  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  business
# 4  43.240875  {'Take-out': True, 'Has TV': False, 'Outdoor S...  business

# %%
# the closed businesses
yelp_df[~yelp_df['open']].head()
# Out:
#                business_id                                       full_address  \
# 5   oLctHIA1AxmsgOuu4dM6Vw             4156 County Rd B\nMc Farland, WI 53558
# 14  HxPpZSY6Q1eARuiahhra6A           6401 University Ave\nMiddleton, WI 53562
# 16  77ESrCo7hQ96VpCWWdvoxg           6230 University Ave\nMiddleton, WI 53562
# 50  IEmqrFe96NOhU07TA0rZdw              6625 Century Ave\nMiddleton, WI 53562
# 62  mbtGl2I2A2To-8jiggN99g  6661 University Ave\nSte 103\nMiddleton, WI 53562
#
#                                                 hours   open  \
# 5                                                  {}  False
# 14                                                 {}  False
# 16  {'Monday': {'close': '21:00', 'open': '06:00'}...  False
# 50                                                 {}  False
# 62  {'Tuesday': {'close': '20:00', 'open': '10:00'...  False
#
#                                            categories        city  \
# 5                   [Television Stations, Mass Media]  Mc Farland
# 14  [Event Planning & Services, Party & Event Plan...   Middleton
# 16                             [Mexican, Restaurants]   Middleton
# 50              [American (Traditional), Restaurants]   Middleton
# 62            [Skin Care, Hair Salons, Beauty & Spas]   Middleton
#
#     review_count                            name neighborhoods  longitude  \
# 5             10          Charter Communications            [] -89.322920
# 14             5   Crandalls Carryout & Catering            [] -89.491800
# 16            17                       Mi Cocina            [] -89.487487
# 50             7  Stamm House At Pheasant Branch            [] -89.494422
# 62             7                         Tangles            [] -89.497265
#
#    state  stars   latitude                                         attributes  \
# 5     WI    1.5  42.968507                                                 {}
# 14    WI    4.0  43.093265  {'Take-out': True, 'Caters': True, 'Attire': '...
# 16    WI    3.0  43.091061  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 50    WI    2.0  43.104535  {'Alcohol': 'full_bar', 'Attire': 'casual', 'P...
# 62    WI    2.0  43.096650  {'By Appointment Only': True, 'Parking': {'gar...
#
#         type
# 5   business
# 14  business
# 16  business
# 50  business
# 62  business

# %% [markdown]
# Notice in an earlier expression we wrote `(yelp_df['state'] == 'AZ') & (yelp_df['review_count'] > 10)`. Normally in Python we use the word `and` when we are working with logic. In Pandas we have to use _bit-wise_ logical operators; all that's important to know is the following equivalencies:
#
# `~` = `not`
# `&` = `and`
# `|` = `or`
#
# We can also use Panda's built-in [string operations](https://pandas.pydata.org/pandas-docs/stable/text.html) for doing pattern matching. For example, there are a lot of businesses in Las Vegas in our data set. However, there are also businesses in 'Las Vegas East' and 'South Las Vegas'. To get all of the Las Vegas businesses I might do the following.

# %%
vegas_yelp_df = yelp_df[yelp_df['city'].str.contains('Vegas')]
vegas_yelp_df.head()
# Out:
#                  business_id  \
# 4348  uzztTCsg3XAKlYqmLO40aw
# 4360  IspFZDcpu9W5NvvJ7QgJZg
# 4364  Dvulg9cc3XHkt5DkBUekhw
# 4441  _SM8UKIwBNbmj1r629ipoQ
# 4489  Zaw0IAXwopKX4MV23MHQRw
#
#                                            full_address  \
# 4348  5835 S Eastern Ave\nSoutheast\nLas Vegas, NV 8...
# 4360  The Forum Shops At Caesars\n3500 Las Vegas Blv...
# 4364  467 E Silverado Ranch Blvd\nSte 175\nSoutheast...
# 4441  1916 Village Center Cir\nSummerlin\nLas Vegas,...
# 4489  2718 E Tropicana Avenue\nEastside\nLas Vegas, ...
#
#                                                   hours   open  \
# 4348  {'Monday': {'close': '21:00', 'open': '10:00'}...   True
# 4360  {'Monday': {'close': '21:00', 'open': '10:00'}...   True
# 4364                                                 {}   True
# 4441  {'Monday': {'close': '23:00', 'open': '11:00'}...  False
# 4489                                                 {}   True
#
#                                              categories       city  \
# 4348  [Arts & Entertainment, Shopping, Books, Mags, ...  Las Vegas
# 4360  [Women's Clothing, Men's Clothing, Fashion, Sh...  Las Vegas
# 4364                       [Hair Salons, Beauty & Spas]  Las Vegas
# 4441  [Wine Bars, Bars, Restaurants, Nightlife, Ital...  Las Vegas
# 4489                             [Car Wash, Automotive]  Las Vegas
#
#       review_count                    name          neighborhoods   longitude  \
# 4348             7  Psychic Eye Book Shops            [Southeast] -115.119422
# 4360             6                     Gap             [Eastside] -115.146372
# 4364            10             Great Clips            [Southeast] -115.153303
# 4441             9            Chianti Cafe            [Summerlin] -115.304396
# 4489             3         Terrible Herbst  [Eastside, Southeast] -115.113492
#
#      state  stars   latitude  \
# 4348    NV    4.5  36.083936
# 4360    NV    4.5  36.124423
# 4364    NV    2.5  36.012150
# 4441    NV    3.5  36.192414
# 4489    NV    1.5  36.100507
#
#                                              attributes      type
# 4348  {'Parking': {'garage': False, 'street': False,...  business
# 4360  {'Parking': {'garage': True, 'street': False, ...  business
# 4364  {'By Appointment Only': False, 'Parking': {'ga...  business
# 4441  {'Alcohol': 'full_bar', 'Music': {'video': Fal...  business
# 4489                                                 {}  business

# %%
vegas_yelp_df['city'].unique()
# Out:
# array(['Las Vegas', 'North Las Vegas', 'N Las Vegas', 'N. Las Vegas',
#        'C Las Vegas', 'Las Vegas ', 'Las Vegas, NV 89147',
#        'Las Vegas East', 'North Las Vegas ', 'N E Las Vegas',
#        'N W Las Vegas', 'Lake Las Vegas', 'South Las Vegas'], dtype=object)

# %%
deforest_yelp_df = yelp_df[yelp_df['city'].str.contains('De Forest')] 
deforest_yelp_df.head()
# Out:
#                   business_id                             full_address  \
# 1      JwUE5GmEO-sH1FuwJgKBlQ  6162 US Highway 51\nDe Forest, WI 53532
# 2      uGykseHzyS5xAMWoN6YUqA      505 W North St\nDe Forest, WI 53532
# 3      LRKJF43s9-3jG9Lgx4zODg    4910 County Rd V\nDe Forest, WI 53532
# 4      RgDg-k9S5YD_BaxMckifkg       631 S Main St\nDe Forest, WI 53532
# 21708  vHV309NwYxjGkvZBnMBp2g       6199 Metro Dr\nDe Forest, WI 53532
#
#                                                    hours  open  \
# 1                                                     {}  True
# 2      {'Monday': {'close': '22:00', 'open': '06:00'}...  True
# 3      {'Monday': {'close': '22:00', 'open': '10:30'}...  True
# 4      {'Monday': {'close': '22:00', 'open': '11:00'}...  True
# 21708                                                 {}  True
#
#                                               categories       city  \
# 1                                          [Restaurants]  De Forest
# 2                  [American (Traditional), Restaurants]  De Forest
# 3      [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                                 [Chinese, Restaurants]  De Forest
# 21708                         [Sporting Goods, Shopping]  De Forest
#
#        review_count                         name neighborhoods  longitude  \
# 1                26         Pine Cone Restaurant            [] -89.335844
# 2                16   Deforest Family Restaurant            [] -89.353437
# 3                 7                     Culver's            [] -89.374983
# 4                 3  Chang Jiang Chinese Kitchen            [] -89.343722
# 21708             8              Gander Mountain            [] -89.328514
#
#       state  stars   latitude  \
# 1        WI    4.0  43.238893
# 2        WI    4.0  43.252267
# 3        WI    4.5  43.251045
# 4        WI    4.0  43.240875
# 21708    WI    3.0  43.186078
#
#                                               attributes      type
# 1      {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 2      {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 3      {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  business
# 4      {'Take-out': True, 'Has TV': False, 'Outdoor S...  business
# 21708  {'Parking': {'garage': False, 'street': False,...  business

# %%
deforest_yelp_df ['city'].unique()
# Out:
# array(['De Forest'], dtype=object)

# %%
#display one field or column
yelp_df['state'].unique()
# Out:
# array(['AZ', 'WI', 'NV', 'NC', 'GA', 'CA', 'ON', 'EDH', 'MLN', 'ELN',
#        'SCB', 'XGL', 'NTH', 'NY', 'FIF', 'KHL', 'MN', 'MA'], dtype=object)

# %%
#dislay two or more columns ?

# %% [markdown]
# ## Applying functions and data aggregation
#
# To analyze the data in the dataframe, we'll need to be able to apply functions to it. Pandas has many mathematical functions built in already, and DataFrames and Series can be passed to NumPy functions (since they behave like NumPy arrays).

# %%
log_review_count = np.log(yelp_df['review_count'])
print(log_review_count.head())
print(log_review_count.shape)
# Out:
# 0    1.945910
# 1    3.258097
# 2    2.772589
# 3    1.945910
# 4    1.098612
# Name: review_count, dtype: float64
# (37938,)

# %%
mean_review_count = yelp_df['review_count'].mean()
print(mean_review_count)
# Out:
# 29.300648426379883

# %% [markdown]
# In the first example we took the _logarithm_ of the review count for each business. In the second case, we calculated the mean review count of all businesses. In the first case, we ended up with a number for each business. We _transformed_ the review counts using the logarithm. In the second case, we _summarized_ the review counts of all the businesses in one number. This summary is a form of _data aggregation_ in which we take many data points and combine them into some smaller representation. The functions we apply to our data sets will either be in the category of **transformations** or **aggregations**.
#
# Sometimes we will need to transform our data in order for it to be usable. For instance, in the `'attributes'` column of our DataFrame, we have a `dict` for each business listing all of its properties. If I wanted to find a restaurant that offers delivery service, it would be difficult for me to filter the DataFrame, even though that information is in the `'attributes'` column. First, I need to transform the `dict` into something more useful.

# %%
def get_delivery_attr(attr_dict):
    return attr_dict.get('Delivery')

# %% [markdown]
# If we give this function a `dict` from the `'attributes'` column, it will look for the `'Delivery'` key. If it finds that key, it returns the value. If it doesn't find the key, it will return none.

# %%
print(get_delivery_attr(yelp_df.loc[0, 'attributes']))
print(get_delivery_attr(yelp_df.loc[1, 'attributes']))
print(get_delivery_attr(yelp_df.loc[2, 'attributes']))
# Out:
# None
# False
# False

# %% [markdown]
# We could iterate over the rows of `yelp_df['attributes']` to get all of the values, but there is a better way. DataFrames and Series have an `apply` method that allows us to apply our function to the entire data set at once, like we did earlier with `np.log`.

# %%
delivery_attr = yelp_df['attributes'].apply(get_delivery_attr)
delivery_attr.head()
# Out:
# 0     None
# 1    False
# 2    False
# 3    False
# 4     None
# Name: attributes, dtype: object

# %% [markdown]
# We can make a new column in our DataFrame with this transformed (and useful) information.

# %%
yelp_df['delivery'] = delivery_attr

# to find businesses that deliver
yelp_df[yelp_df['delivery'].fillna(False)].head()
# Out:
#                business_id                          full_address  \
# 21  KTqNU4plO23583DYAMGXYg  2411 Allen Blvd\nMiddleton, WI 53562
# 64  oc0rCahXOaJeHLzzDdSfyA   1901 Cayuga St\nMiddleton, WI 53562
# 75  OC8AUJshLVimn_-P_INvJw  330 W Main St\nSun Prairie, WI 53590
# 79  NDAxF0_RCZBQedVO_d5WnA  984 W Main St\nSun Prairie, WI 53590
# 82  5uxhIGZlJm9g_zfG_83z5Q  2091 McCoy Rd\nSun Prairie, WI 53590
#
#                                                 hours   open  \
# 21                                                 {}   True
# 64                                                 {}  False
# 75  {'Monday': {'close': '23:00', 'open': '11:00'}...   True
# 79                                                 {}   True
# 82                                                 {}   True
#
#                                          categories         city  \
# 21  [Sandwiches, Pizza, Chicken Wings, Restaurants]    Middleton
# 64                                    [Restaurants]    Middleton
# 75  [Sandwiches, Pizza, Chicken Wings, Restaurants]  Sun Prairie
# 79                           [Chinese, Restaurants]  Sun Prairie
# 82                           [Chinese, Restaurants]  Sun Prairie
#
#     review_count                       name neighborhoods  longitude state  \
# 21             3             Domino's Pizza            [] -89.486219    WI
# 64             3               Soup Factory            [] -89.513737    WI
# 75             4                  Pizza Pit            [] -89.218527    WI
# 79             9                Chang Jiang            [] -89.230477    WI
# 82             6  Peking Chinese Restaurant            [] -89.248245    WI
#
#     stars   latitude                                         attributes  \
# 21    3.0  43.100384  {'Take-out': True, 'Takes Reservations': False...
# 64    3.0  43.096359  {'Take-out': True, 'Alcohol': 'none', 'Takes R...
# 75    2.5  43.183277  {'Take-out': True, 'Good For': {'dessert': Fal...
# 79    3.0  43.180786  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 82    3.0  43.175381  {'Delivery': True, 'Waiter Service': True, 'Ta...
#
#         type delivery
# 21  business     True
# 64  business     True
# 75  business     True
# 79  business     True
# 82  business     True

# %% [markdown]
# It's less common (though possible) to use `apply` on an entire DataFrame rather than just one column. Since a DataFrame might contain many types of data, we won't usually want to apply the same transformation or aggregation across all of the columns.

# %% [markdown]
# ## Data aggregation with `groupby`
#
# Data aggregation is an [_overloaded_](https://en.wikipedia.org/wiki/Function_overloading) term. It refers to both data summarization (as above) but also to the combining of different data sets.
#
# With our Yelp data, we might be interested in comparing the star ratings of businesses in different cities. We could calculate the mean star rating for each city, and this would allow us to easily compare them. First we would have to split up our data by city, calculate the mean for each city, and then combine it back at the end. This procedure is known as [split-apply-combine](https://pandas.pydata.org/pandas-docs/stable/groupby.html) and is a classic example of data aggregation (in the sense of both summarizing data and also combining different data sets).
#
# We achieve the splitting and recombining using the `groupby` method.

# %%
stars_by_city = yelp_df.groupby('city')['stars'].mean()
stars_by_city.head()
# Out:
# city
# Ahwatukee          3.687500
# Anthem             3.781818
# Apache Junction    3.637500
# Arcadia            5.000000
# Atlanta            3.500000
# Name: stars, dtype: float64

# %% [markdown]
# We can also apply multiple functions at once. It might be helpful to know the standard deviation of star ratings, the total number of reviews, and the count of businesses as well.

# %%
agg_by_city = yelp_df.groupby('city').agg({'stars': ['mean', 'std'], 'review_count': 'sum', 
                                           'business_id': 'count',})
agg_by_city.head(10)
# Out:
#                       stars           review_count business_id
#                        mean       std          sum       count
# city
# Ahwatukee          3.687500  1.066955          258           8
# Anthem             3.781818  0.756231          727          55
# Apache Junction    3.637500  1.028010          853          80
# Arcadia            5.000000       NaN            4           1
# Atlanta            3.500000       NaN           16           1
# Avondale           3.538627  0.896959         3488         233
# Black Canyon City  3.000000       NaN            3           1
# Bonnyrigg          3.750000  0.353553            8           2
# Boulder City       4.136364  0.758787          345          22
# Buckeye            3.408451  1.049863          682          71

# %%
# unstacking the columns
new_columns = map(lambda x: '_'.join(x),
                  zip(agg_by_city.columns.get_level_values(0),
                      agg_by_city.columns.get_level_values(1)))
agg_by_city.columns = new_columns
agg_by_city.head()
# Out:
#                  stars_mean  stars_std  review_count_sum  business_id_count
# city
# Ahwatukee          3.687500   1.066955               258                  8
# Anthem             3.781818   0.756231               727                 55
# Apache Junction    3.637500   1.028010               853                 80
# Arcadia            5.000000        NaN                 4                  1
# Atlanta            3.500000        NaN                16                  1

# %% [markdown]
# How does this work? What does `groupby` do? Let's start by inspecting the result of `groupby`.

# %%
by_city = yelp_df.groupby('city')
by_city

# %%
dir(by_city)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_aggregate',
#  '_aggregate_frame',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_apply_whitelist',
#  '_assure_grouper',
#  '_bool_agg',
#  '_builtin_table',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_blocks',
#  '_cython_agg_general',
#  '_cython_table',
#  '_cython_transform',
#  '_define_paths',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_fill',
#  '_get_cython_func',
#  '_get_cythonized_result',
#  '_get_data_to_aggregate',
#  '_get_index',
#  '_get_indices',
#  '_gotitem',
#  '_group_selection',
#  '_insert_inaxis_grouper_inplace',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_iterate_column_groupbys',
#  '_iterate_slices',
#  '_make_wrapper',
#  '_obj_with_exclusions',
#  '_python_agg_general',
#  '_python_apply_general',
#  '_reindex_output',
#  '_reset_cache',
#  '_reset_group_selection',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_set_group_selection',
#  '_set_result_index_ordered',
#  '_transform_fast',
#  '_transform_general',
#  '_transform_item_by_item',
#  '_transform_should_cast',
#  '_try_aggregate_string_function',
#  '_try_cast',
#  '_wrap_agged_blocks',
#  '_wrap_aggregated_output',
#  '_wrap_applied_output',
#  '_wrap_frame_output',
#  '_wrap_transformed_output',
#  'agg',
#  'aggregate',
#  'all',
#  'any',
#  'apply',
#  'attributes',
#  'backfill',
#  'bfill',
#  'boxplot',
#  'business_id',
#  'categories',
#  'city',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cumcount',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'delivery',
#  'describe',
#  'diff',
#  'dtypes',
#  'expanding',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'full_address',
#  'get_group',
#  'groups',
#  'head',
#  'hist',
#  'hours',
#  'idxmax',
#  'idxmin',
#  'indices',
#  'last',
#  'latitude',
#  'longitude',
#  'mad',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'name',
#  'ndim',
#  'neighborhoods',
#  'ngroup',
#  'ngroups',
#  'nth',
#  'nunique',
#  'ohlc',
#  'open',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'prod',
#  'quantile',
#  'rank',
#  'resample',
#  'review_count',
#  'rolling',
#  'sem',
#  'shift',
#  'size',
#  'skew',
#  'stars',
#  'state',
#  'std',
#  'sum',
#  'tail',
#  'take',
#  'transform',
#  'tshift',
#  'type',
#  'var']

# %%
print(type(by_city.groups))
list(by_city.groups.items())[:5]
# Out:
# <class 'dict'>
# [('Ahwatukee',
#   Int64Index([1718, 1740, 13572, 17787, 20361, 22856, 28608, 30499], dtype='int64')),
#  ('Anthem',
#   Int64Index([ 1946,  1948,  1949,  1950,  1951,  1952,  1953,  1954,  1955,
#                1956,  1957,  1958,  1961,  1962, 11455, 12008, 12572, 12870,
#               13007, 13069, 13286, 13500, 13636, 13703, 13744, 13827, 13935,
#               15483, 15581, 15756, 19358, 21295, 21303, 21327, 22354, 22428,
#               22654, 22782, 23215, 24937, 25026, 26116, 26300, 26331, 26841,
#               26937, 30039, 30170, 31565, 32525, 33027, 33492, 33983, 34663,
#               35433],
#              dtype='int64')),
#  ('Apache Junction',
#   Int64Index([ 2392,  2393,  2394,  2395,  2396,  2397,  2398,  2399,  2400,
#                2401,  2402,  2403,  2404,  2406,  2407,  2408,  2409,  2410,
#                2412,  2413,  2414,  2415,  2417,  2418,  2419,  7305,  7524,
#                7525,  7528,  7529,  7530,  7531,  7532,  7533,  7534, 10813,
#               11315, 11660, 12662, 12858, 12893, 13021, 13107, 13367, 13534,
#               13871, 15645, 17769, 19447, 19682, 19695, 20030, 20977, 21940,
#               22571, 22750, 22884, 23175, 23226, 23429, 25839, 26064, 26169,
#               26582, 27131, 27594, 27901, 28112, 28124, 29329, 30062, 30753,
#               30810, 30850, 31841, 33347, 33378, 34415, 34558, 36436],
#              dtype='int64')),
#  ('Arcadia', Int64Index([20625], dtype='int64')),
#  ('Atlanta', Int64Index([16976], dtype='int64'))]

# %%
by_city.get_group('Anthem').head()
# Out:
#                  business_id                                   full_address  \
# 1946  Y0Ife2OJPs5QSL-7dyMF5Q   4250 W Anthem Way\nSte 375\nAnthem, AZ 85086
# 1948  v1ocqAm5soWTNPttLQhSZw   3434 W Anthem Way\nSte 118\nAnthem, AZ 85086
# 1949  HMDymN9TbFUln9AkqHMpVw            4250 W Anthem Way\nAnthem, AZ 85086
# 1950  XJv7dUb5fMRaZAWVZjhtvw            4250 W Anthem Way\nAnthem, AZ 85086
# 1951  xPDbCj9tfp5nnGzYzoCHwA  3655 W Anthem Way\nSte C105\nAnthem, AZ 85086
#
#      hours  open                              categories    city  \
# 1946    {}  True        [Fashion, Shopping, Shoe Stores]  Anthem
# 1948    {}  True                  [Chinese, Restaurants]  Anthem
# 1949    {}  True  [Department Stores, Fashion, Shopping]  Anthem
# 1950    {}  True               [Shopping, Outlet Stores]  Anthem
# 1951    {}  True               [Sandwiches, Restaurants]  Anthem
#
#       review_count                             name neighborhoods   longitude  \
# 1946             8               Nike Factory Store            [] -112.150162
# 1948            50                    Shanghai Club            [] -112.135305
# 1949             3  Polo Ralph Lauren Factory Store            [] -112.151046
# 1950            64                Outlets At Anthem            [] -112.149875
# 1951             6                           Subway            [] -112.138854
#
#      state  stars   latitude  \
# 1946    AZ    4.0  33.874003
# 1948    AZ    3.5  33.864429
# 1949    AZ    3.0  33.875410
# 1950    AZ    3.5  33.873311
# 1951    AZ    3.0  33.864913
#
#                                              attributes      type delivery
# 1946  {'Parking': {'garage': False, 'street': False,...  business     None
# 1948  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  business    False
# 1949  {'Parking': {'garage': False, 'street': False,...  business     None
# 1950  {'Parking': {'garage': False, 'street': False,...  business     None
# 1951  {'Ambience': {'romantic': False, 'intimate': F...  business     None

# %%
by_city.get_group('De Forest').head()
# Out:
#                   business_id                             full_address  \
# 1      JwUE5GmEO-sH1FuwJgKBlQ  6162 US Highway 51\nDe Forest, WI 53532
# 2      uGykseHzyS5xAMWoN6YUqA      505 W North St\nDe Forest, WI 53532
# 3      LRKJF43s9-3jG9Lgx4zODg    4910 County Rd V\nDe Forest, WI 53532
# 4      RgDg-k9S5YD_BaxMckifkg       631 S Main St\nDe Forest, WI 53532
# 21708  vHV309NwYxjGkvZBnMBp2g       6199 Metro Dr\nDe Forest, WI 53532
#
#                                                    hours  open  \
# 1                                                     {}  True
# 2      {'Monday': {'close': '22:00', 'open': '06:00'}...  True
# 3      {'Monday': {'close': '22:00', 'open': '10:30'}...  True
# 4      {'Monday': {'close': '22:00', 'open': '11:00'}...  True
# 21708                                                 {}  True
#
#                                               categories       city  \
# 1                                          [Restaurants]  De Forest
# 2                  [American (Traditional), Restaurants]  De Forest
# 3      [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                                 [Chinese, Restaurants]  De Forest
# 21708                         [Sporting Goods, Shopping]  De Forest
#
#        review_count                         name neighborhoods  longitude  \
# 1                26         Pine Cone Restaurant            [] -89.335844
# 2                16   Deforest Family Restaurant            [] -89.353437
# 3                 7                     Culver's            [] -89.374983
# 4                 3  Chang Jiang Chinese Kitchen            [] -89.343722
# 21708             8              Gander Mountain            [] -89.328514
#
#       state  stars   latitude  \
# 1        WI    4.0  43.238893
# 2        WI    4.0  43.252267
# 3        WI    4.5  43.251045
# 4        WI    4.0  43.240875
# 21708    WI    3.0  43.186078
#
#                                               attributes      type delivery
# 1      {'Take-out': True, 'Good For': {'dessert': Fal...  business    False
# 2      {'Take-out': True, 'Good For': {'dessert': Fal...  business    False
# 3      {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  business    False
# 4      {'Take-out': True, 'Has TV': False, 'Outdoor S...  business     None
# 21708  {'Parking': {'garage': False, 'street': False,...  business     None

# %% [markdown]
# When we use `groupby` on a column, Pandas builds a `dict`, using the unique elements of the column as the keys and the index of the rows in each group as the values. This `dict` is stored in the `groups` attribute. Pandas can then use this `dict` to direct the application of aggregating functions over the different groups.

# %% [markdown]
# ## Sorting
#
# Even though the DataFrame in many ways behaves similarly to a `dict`, it also is ordered. Therefore we can sort the data in it. Pandas provides two sorting methods, `sort_values` and `sort_index`.

# %%
yelp_df.sort_values('stars').head()
# Out:
#                   business_id  \
# 36220  2Q2tZ0yQo25cni0PT2j0Zw
# 27946  cHvL85QIV-L2-YlLOcwlCw
# 36332  e23Sa3FCTaIOSZzJsT8sIQ
# 7488   fZO5Fghc6Q07jU8EROzj6Q
# 3370   JjdjS5n6ILh-d3GeTD6qkA
#
#                                             full_address  \
# 36220  6420 Spring Mountain Rd\nChinatown\nLas Vegas,...
# 27946         5235 S Kyrene Rd\nSte 106\nTempe, AZ 85283
# 36332       3949 N Drinkwater Blvd\nScottsdale, AZ 85251
# 7488                    2431 E Laurel St\nMesa, AZ 85213
# 3370       15820 N 84th St\nSte 25\nScottsdale, AZ 85260
#
#                                                    hours  open  \
# 36220                                                 {}  True
# 27946  {'Monday': {'close': '18:00', 'open': '10:00'}...  True
# 36332                                                 {}  True
# 7488                                                  {}  True
# 3370   {'Monday': {'close': '17:00', 'open': '09:00'}...  True
#
#                                               categories        city  \
# 36220  [Real Estate Services, Property Management, Ho...   Las Vegas
# 27946  [Sporting Goods, Shopping, Golf Equipment, Out...       Tempe
# 36332  [Professional Services, Internet Service Provi...  Scottsdale
# 7488                      [Home Services, Pool Cleaners]        Mesa
# 3370                [Hotels & Travel, Motorcycle Rental]  Scottsdale
#
#        review_count                            name neighborhoods   longitude  \
# 36220             3     Total Real Eatate of Nevada   [Chinatown] -115.232316
# 27946             3              Custom Golf Center            [] -111.945955
# 36332             3                       Cox Cable            [] -111.921620
# 7488              6  Foster's Pool Service & Repair            [] -111.778212
# 3370              3               Top Spoke Rentals            [] -111.900187
#
#       state  stars   latitude attributes      type delivery
# 36220    NV    1.0  36.125870         {}  business     None
# 27946    AZ    1.0  33.376734         {}  business     None
# 36332    AZ    1.0  33.493469         {}  business     None
# 7488     AZ    1.0  33.457833         {}  business     None
# 3370     AZ    1.0  33.629858         {}  business     None

# %%
yelp_df.set_index('business_id').sort_index().head()
# Out:
#                                                              full_address  \
# business_id
# --1emggGHgoG6ipd_RMb-g  3280 S Decatur Blvd\nWestside\nLas Vegas, NV 8...
# --4Pe8BZ6gj57VFL5mUE8g     21001 North Tatum Blvd. #24\nPhoenix, AZ 85050
# --5jkZ3-nUPZxUvtcbr8Uw         1336 N Scottsdale Rd\nScottsdale, AZ 85257
# --BlvDO_RG2yElKu9XA1_g  14870 N Northsight Blvd\nSte 103\nScottsdale, ...
# --Dl2rW_xO8GuYBomlg9zw  4505 S Maryland Pkwy\nUniversity\nLas Vegas, N...
#
#                                                                     hours  \
# business_id
# --1emggGHgoG6ipd_RMb-g                                                 {}
# --4Pe8BZ6gj57VFL5mUE8g                                                 {}
# --5jkZ3-nUPZxUvtcbr8Uw  {'Monday': {'close': '21:00', 'open': '11:00'}...
# --BlvDO_RG2yElKu9XA1_g  {'Monday': {'close': '21:00', 'open': '10:30'}...
# --Dl2rW_xO8GuYBomlg9zw                                                 {}
#
#                         open                                    categories  \
# business_id
# --1emggGHgoG6ipd_RMb-g  True                    [Food, Convenience Stores]
# --4Pe8BZ6gj57VFL5mUE8g  True                  [Shopping, Office Equipment]
# --5jkZ3-nUPZxUvtcbr8Uw  True                          [Greek, Restaurants]
# --BlvDO_RG2yElKu9XA1_g  True  [Sushi Bars, Hawaiian, Chinese, Restaurants]
# --Dl2rW_xO8GuYBomlg9zw  True           [Medical Centers, Health & Medical]
#
#                               city  review_count                        name  \
# business_id
# --1emggGHgoG6ipd_RMb-g   Las Vegas             4                    Sinclair
# --4Pe8BZ6gj57VFL5mUE8g     Phoenix             5                  Office Max
# --5jkZ3-nUPZxUvtcbr8Uw  Scottsdale            42                Mika's Greek
# --BlvDO_RG2yElKu9XA1_g  Scottsdale            65                Asian Island
# --Dl2rW_xO8GuYBomlg9zw   Las Vegas             6  UNLV Student Health Center
#
#                        neighborhoods   longitude state  stars   latitude  \
# business_id
# --1emggGHgoG6ipd_RMb-g    [Westside] -115.207238    NV    4.0  36.130531
# --4Pe8BZ6gj57VFL5mUE8g            [] -111.974607    AZ    3.0  33.678615
# --5jkZ3-nUPZxUvtcbr8Uw            [] -111.926908    AZ    4.5  33.463373
# --BlvDO_RG2yElKu9XA1_g            [] -111.897836    AZ    4.0  33.620568
# --Dl2rW_xO8GuYBomlg9zw  [University] -115.141514    NV    4.0  36.110940
#
#                                                                attributes  \
# business_id
# --1emggGHgoG6ipd_RMb-g  {'Parking': {'garage': False, 'street': False,...
# --4Pe8BZ6gj57VFL5mUE8g  {'Parking': {'garage': False, 'street': False,...
# --5jkZ3-nUPZxUvtcbr8Uw  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# --BlvDO_RG2yElKu9XA1_g  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# --Dl2rW_xO8GuYBomlg9zw                      {'By Appointment Only': True}
#
#                             type delivery
# business_id
# --1emggGHgoG6ipd_RMb-g  business     None
# --4Pe8BZ6gj57VFL5mUE8g  business     None
# --5jkZ3-nUPZxUvtcbr8Uw  business    False
# --BlvDO_RG2yElKu9XA1_g  business     True
# --Dl2rW_xO8GuYBomlg9zw  business     None

# %% [markdown]
# Don't forget that most Pandas operations return a copy of the DataFrame, and do not update the DataFrame in place (unless we tell it to)!

# %% [markdown]
# ## Joining data sets
# Often we will want to augment one data set with data from another. For instance, businesses in big cities probably get more reviews than those in small cities. It could be useful to scale the review counts by the city's population. To do that, we'll need to add population data to the Yelp data. We can get population data from the US census.

# %%
census_df = pd.read_csv('./data/PEP_2016_PEPANNRES.csv', skiprows=[1])
 
census_df.head()
# Out:
#                 GEO.id    GEO.id2  \
# 0  0610000US0900104720  900104720
# 1  0610000US0900108070  900108070
# 2  0610000US0900108980  900108980
# 3  0610000US0900118500  900118500
# 4  0610000US0900118850  900118850
#
#                                 GEO.display-label  rescen42010  resbase42010  \
# 0      Bethel town, Fairfield County, Connecticut      18584.0         18584
# 1  Bridgeport town, Fairfield County, Connecticut     144229.0        144236
# 2  Brookfield town, Fairfield County, Connecticut      16452.0         16452
# 3     Danbury town, Fairfield County, Connecticut      80893.0         80903
# 4      Darien town, Fairfield County, Connecticut      20732.0         20732
#
#    respop72010  respop72011  respop72012  respop72013  respop72014  \
# 0        18642        18942        19150        19267        19316
# 1       144912       146226       146962       147666       147560
# 2        16483        16635        16785        16859        17016
# 3        81356        82182        82788        83678        83687
# 4        20777        20975        21127        21342        21641
#
#    respop72015  respop72016
# 0        19463        19627
# 1       147090       145936
# 2        17087        17098
# 3        84236        84992
# 4        21718        21744

# %%
# construct city & state fields
census_df['city'] = census_df['GEO.display-label'].apply(lambda x: x.split(', ')[0])
census_df['state'] = census_df['GEO.display-label'].apply(lambda x: x.split(', ')[2])

# %%
# convert state names to abbreviations

print(census_df['state'].unique())
# Out:
# ['Connecticut' 'Illinois' 'Indiana' 'Kansas' 'Maine' 'Massachusetts'
#  'Michigan' 'Minnesota' 'Missouri' 'Nebraska' 'New Hampshire' 'New Jersey'
#  'New York' 'North Dakota' 'Ohio' 'Pennsylvania' 'Rhode Island'
#  'South Dakota' 'Vermont' 'Wisconsin']

# %%
state_abbr = dict(zip(census_df['state'].unique(), ['CT', 'IL', 'IN', 'KS', 'ME', 'MA', 'MI', 'MN', 'MO', 'NE', 
                                                 'NH', 'NJ', 'NY', 'ND', 'OH', 'PA', 'RI', 'SD', 'VT', 'WI']))

# %%
census_df['state'] = census_df['state'].replace(state_abbr)

# %%
# remove last word (e.g. 'city', 'town', township', 'borough', 'village') from city names

census_df['city'] = census_df['city'].apply(lambda x: ' '.join(x.split(' ')[:-1]))

# %%
merged_df = yelp_df.merge(census_df, on=['state', 'city'])
merged_df.head()
# Out:
#               business_id                              full_address  \
# 0  HxPpZSY6Q1eARuiahhra6A  6401 University Ave\nMiddleton, WI 53562
# 1  HxPpZSY6Q1eARuiahhra6A  6401 University Ave\nMiddleton, WI 53562
# 2  SKLw05kEIlZcpTD5pqma8Q      2039 Allen Blvd\nMiddleton, WI 53562
# 3  SKLw05kEIlZcpTD5pqma8Q      2039 Allen Blvd\nMiddleton, WI 53562
# 4  77ESrCo7hQ96VpCWWdvoxg  6230 University Ave\nMiddleton, WI 53562
#
#                                                hours   open  \
# 0                                                 {}  False
# 1                                                 {}  False
# 2  {'Monday': {'close': '14:00', 'open': '11:00'}...   True
# 3  {'Monday': {'close': '14:00', 'open': '11:00'}...   True
# 4  {'Monday': {'close': '21:00', 'open': '06:00'}...  False
#
#                                           categories       city  review_count  \
# 0  [Event Planning & Services, Party & Event Plan...  Middleton             5
# 1  [Event Planning & Services, Party & Event Plan...  Middleton             5
# 2  [Party & Event Planning, Asian Fusion, Event P...  Middleton            41
# 3  [Party & Event Planning, Asian Fusion, Event P...  Middleton            41
# 4                             [Mexican, Restaurants]  Middleton            17
#
#                                  name neighborhoods  longitude  ...  \
# 0       Crandalls Carryout & Catering            [] -89.491800  ...
# 1       Crandalls Carryout & Catering            [] -89.491800  ...
# 2  Imperial Garden Chinese Restaurant            [] -89.485169  ...
# 3  Imperial Garden Chinese Restaurant            [] -89.485169  ...
# 4                           Mi Cocina            [] -89.487487  ...
#
#                         GEO.display-label  rescen42010  resbase42010  \
# 0  Middleton city, Dane County, Wisconsin      17442.0         17558
# 1  Middleton town, Dane County, Wisconsin       5877.0          5831
# 2  Middleton city, Dane County, Wisconsin      17442.0         17558
# 3  Middleton town, Dane County, Wisconsin       5877.0          5831
# 4  Middleton city, Dane County, Wisconsin      17442.0         17558
#
#   respop72010 respop72011 respop72012 respop72013  respop72014 respop72015  \
# 0       17622       17903       18271       18522        18694       18955
# 1        5845        5943        6030        6086         6140        6179
# 2       17622       17903       18271       18522        18694       18955
# 3        5845        5943        6030        6086         6140        6179
# 4       17622       17903       18271       18522        18694       18955
#
#    respop72016
# 0        19109
# 1         6257
# 2        19109
# 3         6257
# 4        19109
#
# [5 rows x 28 columns]

# %% [markdown]
# The `merge` function looks through the `'state'` and `'city'` columns of `yelp_df` and `census_df` and tries to match up rows that share values. When a match is found, the rows are combined. What happens when a match is not found? We can imagine four scenarios:
#
# 1. We only keep rows from `yelp_df` and `census_df` if they match. Any rows from either table that have no match are discarded. This is called an _inner join_.
#
# 2. We keep all rows from `yelp_df` and `census_df`, even if they have no match. In this case, when a row in `yelp_df` has no match in `census_df`, all the columns from `census_df` are merged in with null values. When a row in `census_df` has no match in `yelp_df`, all the columns from `yelp_df` are merged in with null values. This is called an _outer join_.
#
# 3. We privilege the `yelp_df` data. If a row in `yelp_df` has no match in `census`, we keep it and fill in the missing `census_df` columns as null values. If a row in `census` has no match in `yelp_df`, we discard it. This is called a _left join_.
#
# 4. We privilege the `census_df` data. This is called a _right join_.
#
# The default behavior for Pandas is case #1, the _inner join_. This means if there are cities in `yelp_df` that we don't have matching `census_df` data for, they are dropped. Therefore, `merged_df` might be smaller than `yelp_df`.

# %%
print(yelp_df.shape)
print(merged_df.shape)
# Out:
# (37938, 16)
# (3598, 28)

# %% [markdown]
# There are a lot of cities in `yelp_df` that aren't in `census_df`! We might want to keep these rows, but we don't need any census data where there are no businesses. Then we should use a _left join_.

# %%
merged_df = yelp_df.merge(census_df, on=['state', 'city'], how='left')
print(yelp_df.shape)
print(merged_df.shape)
# Out:
# (37938, 16)
# (39648, 28)

# %% [markdown]
# Sometimes we don't need to merge together the columns of separate data sets, but just need to add more rows. For example, the New York City subway system [releases data about how many customers enter and exit the station each week](http://web.mta.info/developers/turnstile.html). Each weekly data set has the same columns, so if we want multiple weeks of data, we just have to append one week to another.

# %%
nov18 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_171118.txt')
nov11 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_171111.txt')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1239         """Send a complete request to the server."""
# -> 1240         self._send_request(method, url, body, headers, encode_chunked)
#    1241
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1285             body = _encode(body, 'body')
# -> 1286         self.endheaders(body, encode_chunked=encode_chunked)
#    1287
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1234             raise CannotSendHeader()
# -> 1235         self._send_output(message_body, encode_chunked=encode_chunked)
#    1236
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1005         del self._buffer[:]
# -> 1006         self.send(msg)
#    1007
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     945             if self.auto_open:
# --> 946                 self.connect()
#     947             else:
#
# ~\anaconda3\lib\http\client.py in connect(self)
#     916         """Connect to the host and port specified in __init__."""
# --> 917         self.sock = self._create_connection(
#     918             (self.host,self.port), self.timeout, self.source_address)
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     786     err = None
# --> 787     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-124-0aaa2fb31bf3> in <module>
# ----> 1 nov18 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_171118.txt')
#       2 nov11 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_171111.txt')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     428     # though mypy handling of conditional imports is difficult.
#     429     # See https://github.com/python/mypy/issues/1297
# --> 430     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
#     431         filepath_or_buffer, encoding, compression
#     432     )
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     170
#     171     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
# --> 172         req = urlopen(filepath_or_buffer)
#     173         content_encoding = req.headers.get("Content-Encoding", None)
#     174         if content_encoding == "gzip":
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     139     import urllib.request
#     140
# --> 141     return urllib.request.urlopen(*args, **kwargs)
#     142
#     143
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_open(self, req)
#    1377
#    1378     def http_open(self, req):
# -> 1379         return self.do_open(http.client.HTTPConnection, req)
#    1380
#    1381     http_request = AbstractHTTPHandler.do_request_
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
# -> 1353                 raise URLError(err)
#    1354             r = h.getresponse()
#    1355         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
nov11.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6393563
# 1  REGULAR  6393595
# 2  REGULAR  6393616
# 3  REGULAR  6393742
# 4  REGULAR  6394021
#
#    EXITS
# 0                                            2162811
# 1                                            2162822
# 2                                            2162855
# 3                                            2162933
# 4                                            2162992

# %%
nov18.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6402636
# 1  REGULAR  6402645
# 2  REGULAR  6402717
# 3  REGULAR  6402857
# 4  REGULAR  6403178
#
#    EXITS
# 0                                            2166100
# 1                                            2166112
# 2                                            2166175
# 3                                            2166230
# 4                                            2166292

# %%
nov = pd.concat([nov18, nov11])
nov['DATE'].unique()
# Out:
# array(['11/11/2017', '11/12/2017', '11/13/2017', '11/14/2017',
#        '11/15/2017', '11/16/2017', '11/17/2017', '11/04/2017',
#        '11/05/2017', '11/06/2017', '11/07/2017', '11/08/2017',
#        '11/09/2017', '11/10/2017'], dtype=object)

# %%
city_counts = yelp_df.groupby('city')['business_id'].count().rename('city_counts')
city_counts.head()
# Out:
# city
# Ahwatukee           8
# Anthem             55
# Apache Junction    80
# Arcadia             1
# Atlanta             1
# Name: city_counts, dtype: int64

# %%
pd.concat([yelp_df.set_index('city'), city_counts], axis=1, join='inner').reset_index().head()
# Out:
#         city             business_id  \
# 0    Phoenix  vcNAWiLM4dR7D2nwwJ7nCA
# 1  De Forest  JwUE5GmEO-sH1FuwJgKBlQ
# 2  De Forest  uGykseHzyS5xAMWoN6YUqA
# 3  De Forest  LRKJF43s9-3jG9Lgx4zODg
# 4  De Forest  RgDg-k9S5YD_BaxMckifkg
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours  open  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  True
# 1                                                 {}  True
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  True
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  True
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  True
#
#                                           categories  review_count  \
# 0                        [Doctors, Health & Medical]             7
# 1                                      [Restaurants]            26
# 2              [American (Traditional), Restaurants]            16
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...             7
# 4                             [Chinese, Restaurants]             3
#
#                           name neighborhoods   longitude state  stars  \
# 0            Eric Goldberg, MD            [] -111.983758    AZ    3.5
# 1         Pine Cone Restaurant            []  -89.335844    WI    4.0
# 2   Deforest Family Restaurant            []  -89.353437    WI    4.0
# 3                     Culver's            []  -89.374983    WI    4.5
# 4  Chang Jiang Chinese Kitchen            []  -89.343722    WI    4.0
#
#     latitude                                         attributes      type  \
# 0  33.499313                      {'By Appointment Only': True}  business
# 1  43.238893  {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 2  43.252267  {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 3  43.251045  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  business
# 4  43.240875  {'Take-out': True, 'Has TV': False, 'Outdoor S...  business
#
#   delivery  city_counts
# 0     None         6715
# 1    False            6
# 2    False            6
# 3    False            6
# 4     None            6

# %% [markdown]
# Pandas provides [extensive documentation](https://pandas.pydata.org/pandas-docs/stable/merging.html) with diagrammed examples on different met

# %% [markdown]
# ## Working with time series
# Pandas has a well-designed backend for inferring dates and times from strings and doing meaningful computations with them.

# %%
pop_growth = pd.read_html('https://web.archive.org/web/20170127165708/https://www.census.gov/population/international/data/worldpop/table_population.php', attrs={'class': 'query_table'}, parse_dates=[0])[0]
pop_growth.dropna(inplace=True)
pop_growth.head()
# Out:
#         Year    Population  Annual Growth Rate (%)  Annual Population Change
# 0 1950-01-01  2.557629e+09                   1.459                37311223.0
# 1 1951-01-01  2.594940e+09                   1.612                41832429.0
# 2 1952-01-01  2.636772e+09                   1.717                45281083.0
# 3 1953-01-01  2.682053e+09                   1.796                48174715.0
# 4 1954-01-01  2.730228e+09                   1.900                51870839.0

# %%
pop_growth.info
# Out:
# <bound method DataFrame.info of               Population  Annual Growth Rate (%)  Annual Population Change
# Year
# 1950-01-01  2.557629e+09                   1.459                37311223.0
# 1951-01-01  2.594940e+09                   1.612                41832429.0
# 1952-01-01  2.636772e+09                   1.717                45281083.0
# 1953-01-01  2.682053e+09                   1.796                48174715.0
# 1954-01-01  2.730228e+09                   1.900                51870839.0
# ...                  ...                     ...                       ...
# 2045-01-01  9.148985e+09                   0.516                47237518.0
# 2046-01-01  9.196222e+09                   0.502                46210494.0
# 2047-01-01  9.242433e+09                   0.488                45138181.0
# 2048-01-01  9.287571e+09                   0.474                44027603.0
# 2049-01-01  9.331598e+09                   0.460                42885822.0
#
# [100 rows x 3 columns]>

# %%
pop_growth.reset_index('Year', inplace=True)

# %%
pop_growth.head()
# Out:
#         Year    Population  Annual Growth Rate (%)  Annual Population Change
# 0 1950-01-01  2.557629e+09                   1.459                37311223.0
# 1 1951-01-01  2.594940e+09                   1.612                41832429.0
# 2 1952-01-01  2.636772e+09                   1.717                45281083.0
# 3 1953-01-01  2.682053e+09                   1.796                48174715.0
# 4 1954-01-01  2.730228e+09                   1.900                51870839.0

# %%
pop_growth.columns.unique()
# Out:
# Index(['Year', 'Population', 'Annual Growth Rate (%)',
#        'Annual Population Change'],
#       dtype='object')

# %%
pop_growth.resample('10AS').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-bdb8114beef3> in <module>
# ----> 1 pop_growth.resample('10AS').mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8102
#    8103         axis = self._get_axis_number(axis)
# -> 8104         return resample(
#    8105             self,
#    8106             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1401             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1402
# -> 1403         raise TypeError(
#    1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %% [markdown]
# This kind of resampling is called _downsampling_, because we are decreasing the sampling frequency of the data. We can choose how to aggregate the data from each decade (e.g. `mean`). Options for aggregation include `mean`, `median`, `sum`, `last`, and `first`.
#
# We can also _upsample_ data. In this case, we don't have data for each quarter, so we have to tell Pandas has to fill in the missing data.

# %%
pop_growth.resample('1Q').bfill().head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-ff7549dd2047> in <module>
# ----> 1 pop_growth.resample('1Q').bfill().head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8102
#    8103         axis = self._get_axis_number(axis)
# -> 8104         return resample(
#    8105             self,
#    8106             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1401             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1402
# -> 1403         raise TypeError(
#    1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
pop_growth.resample('1Q').ffill().head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-372be522f578> in <module>
# ----> 1 pop_growth.resample('1Q').ffill().head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8102
#    8103         axis = self._get_axis_number(axis)
# -> 8104         return resample(
#    8105             self,
#    8106             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1401             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1402
# -> 1403         raise TypeError(
#    1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
print(pd.Timestamp('January 8, 2017'))
print(pd.Timestamp('01/08/17 20:13'))
print(pd.Timestamp(1.4839*10**18))
# Out:
# 2017-01-08 00:00:00
# 2017-01-08 20:13:00
# 2017-01-08 18:26:40

# %%
print(pd.Timestamp('Feb. 11 2016 2:30 am') - pd.Timestamp('2015-08-03 5:14 pm'))
# Out:
# 191 days 09:16:00

# %%
from pandas.tseries.offsets import BDay, Day, BMonthEnd

print(pd.Timestamp('January 9, 2017') - Day(4))
print(pd.Timestamp('January 9, 2017') - BDay(4))
print(pd.Timestamp('January 9, 2017') + BMonthEnd(4))
# Out:
# 2017-01-05 00:00:00
# 2017-01-03 00:00:00
# 2017-04-28 00:00:00

# %% [markdown]
# If we're entering time series data into a DataFrame it will often be useful to create a range of dates.

# %%
pd.date_range(start='1/8/2017', end='3/2/2017', freq='B')
# Out:
# DatetimeIndex(['2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-16', '2017-01-17', '2017-01-18',
#                '2017-01-19', '2017-01-20', '2017-01-23', '2017-01-24',
#                '2017-01-25', '2017-01-26', '2017-01-27', '2017-01-30',
#                '2017-01-31', '2017-02-01', '2017-02-02', '2017-02-03',
#                '2017-02-06', '2017-02-07', '2017-02-08', '2017-02-09',
#                '2017-02-10', '2017-02-13', '2017-02-14', '2017-02-15',
#                '2017-02-16', '2017-02-17', '2017-02-20', '2017-02-21',
#                '2017-02-22', '2017-02-23', '2017-02-24', '2017-02-27',
#                '2017-02-28', '2017-03-01', '2017-03-02'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# The `Timestamp` class is compatible with Python's `datetime` module.

# %%
import datetime

pd.Timestamp('May 1, 2017') - datetime.datetime(2017, 1, 8)
# Out:
# Timedelta('113 days 00:00:00')

# %% [markdown]
# ## Visualizing data with Pandas
#
# Visualizing a data set is an important first step in drawing insights. We can easily pass data from Pandas to Matplotlib for visualizations, but Pandas also plugs into Matplotlib directly through methods like `plot` and `hist`.

# %%
yelp_df['review_count'].apply(np.log).hist(bins=30)

# %%
pop_growth['Annual Growth Rate (%)'].plot()

# %% [markdown]
# The [plotting functions take many parameters](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) for customizing the appearance of the output. Since they are essentially a wrapper around the Matplotlib functions, they also accept many of the Matplotlib parameters, not all of which are listed in the Pandas documentation. Pandas provides [a guide](https://pandas.pydata.org/pandas-docs/stable/visualization.html) to making various plots from DataFrames.

# %% [markdown]
# *Copyright &copy; 2020 The Data Incubator.  All rights reserved.*
# **Edited by Chisomloius**
